# %% [markdown]
# <h1>Comparison of Transfer Learning Models - Frontal View </h1>
#
# <hr>
#
# <p>Within TensorFlow, there are 71 architectures available for Transfer Learning. From these, we have selected 12 for evaluation, testing each over the course of just 5 epochs. We plot a graph to illustrate the relationship between accuracy and the number of parameters within each model. Our objective is to identify a model that minimizes the number of parameters required, while simultaneously maximizing accuracy. It's important to note that, at present, we are not employing any form of data augmentations.</p>

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import inspect
import glob
import os
import matplotlib.image as mpimg
import numpy as np
import seaborn as sns
import pandas as pd
import inspect
from tqdm import tqdm
from keras.preprocessing import image
from sklearn import metrics
from sklearn.metrics import ConfusionMatrixDisplay
from google.colab import drive

from sklearn.model_selection import StratifiedKFold

# %%
from keras.preprocessing import image

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
batch_size = 32
data_path = "/content/drive/MyDrive/sve_F-bez augumentacije/Train"
n_folds =5
kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
all_files = glob.glob(os.path.join(data_path, '*/*'))
labels = [os.path.basename(os.path.dirname(fp)) for fp in all_files]

# %%
# List all available models
model_dictionary = {m[0]:m[1] for m in inspect.getmembers(tf.keras.applications, inspect.isfunction)}

# %%
len(model_dictionary)
# Out:
# 71

# %%
new_model_dict = {key: model_dictionary[key] for key in model_dictionary  if key in ['MobileNetV2', 'MobileNet', 'EfficientNetB0', 'DenseNet121','VGG16', 'VGG19', 'Xception', 'InceptionV3','ResNet50V2','ResNet50', 'ResNet101V2', 'ResNet101']}

# %%
len(new_model_dict)
# Out:
# 12

# %%
def preprocess_data_for_fold(train_files, val_files, img_size):
    datagen = image.ImageDataGenerator(rescale=1./255.)

    # Extracting the labels from the directory structure
    train_labels = [os.path.basename(os.path.dirname(fp)) for fp in train_files]
    val_labels = [os.path.basename(os.path.dirname(fp)) for fp in val_files]

    train_gen = datagen.flow_from_dataframe(
        dataframe=pd.DataFrame({'filename': train_files, 'class': train_labels}),
        directory=None,
        x_col="filename",
        y_col="class",
        class_mode="binary",
        target_size=img_size,
        batch_size=batch_size,
        shuffle=True
    )

    val_gen = datagen.flow_from_dataframe(
        dataframe=pd.DataFrame({'filename': val_files, 'class': val_labels}),
        directory=None,
        x_col="filename",
        y_col="class",
        class_mode="binary",
        target_size=img_size,
        batch_size=batch_size,
        shuffle=False
    )

    return train_gen, val_gen

# %%
def test_preprocces(img_size):
  test_datagen = image.ImageDataGenerator(rescale=1./255.)
  test_generator = test_datagen.flow_from_directory("/content/drive/MyDrive/sve_F-bez augumentacije/Test",
                                        target_size=img_size,
                                        class_mode='binary',
                                        batch_size=batch_size,
                                        shuffle=False)
  return test_generator

# %%
def build_model(model_1,input_shape):
    pre_trained_model = model_1(include_top=False, pooling='avg', input_shape=input_shape)
    pre_trained_model.trainable = False

    model = tf.keras.models.Sequential()
    model.add(pre_trained_model)
    model.add(tf.keras.layers.Dense(1, activation='sigmoid'))
    model.compile(optimizer='adam',loss='binary_crossentropy', metrics=['accuracy'])
    return model

# %%
# Loop over each model available in Keras
model_benchmarks = {'model_name': [], 'num_model_params': [], 'validation_accuracy': [], 'test_accuracy': []}
for model_name, model_1 in tqdm(list(new_model_dict.items())[:6]):
    # Special handling for "NASNetLarge" since it requires input images with size (331,331)

    fold_no = 1
    all_acc = []
    all_loss = []

    for train_indices, val_indices in kfold.split(all_files,labels):
        print('------------------------------------------------------------------------')
        print(f'Training for fold {fold_no} ...')

    # Preprocess data and build model (assuming these functions are defined)
        train_files = [all_files[i] for i in train_indices]
        val_files = [all_files[i] for i in val_indices]
        if 'NASNetLarge' in model_name:
          img_size =(331,331)
          input_shape =(331,331,3)
          train_gen, val_gen = preprocess_data_for_fold(train_files, val_files, img_size)
        elif 'InceptionResNetV2' or 'InceptionV3' or 'Xception' in model_name:
          img_size=(299,299)
          input_shape=(299,299,3)
          train_gen, val_gen = preprocess_data_for_fold(train_files, val_files, img_size)
        else:
          img_size=(224,224)
          input_shape=(224,224,3)
          train_gen, val_gen = preprocess_data_for_fold(train_files, val_files, img_size)


        model = build_model(model_1,input_shape)

    # Fit data to model
        history = model.fit(train_gen, epochs=5, validation_data=val_gen)

    # Evaluate the model on validation set
        scores = model.evaluate(val_gen, verbose=0)
        print(f'Score for fold {fold_no}: Loss of {scores[0]}; Accuracy of {round(scores[1]*100, 2)}%')
        all_acc.append(scores[1] * 100)
        all_loss.append(scores[0])

    # Increase fold number
        fold_no += 1

# Provide average scores
    print('------------------------------------------------------------------------')
    print('Score per fold')
    for i in range(len(all_acc)):
        print('------------------------------------------------------------------------')
        print(f'> Fold {i+1} - Loss: {all_loss[i]} - Accuracy: {all_acc[i]}%')
    print('------------------------------------------------------------------------')
    print('Average scores for all folds:')
    print(f'> Accuracy: {np.mean(all_acc)} (+- {np.std(all_acc)})')
    print(f'> Loss: {np.mean(all_loss)}')
    print('------------------------------------------------------------------------')
    if 'NASNetLarge' in model_name:
        test_processed = test_preprocces(img_size)
    elif 'InceptionResNetV2' or 'InceptionV3' or 'Xception' in model_name:
        test_processed = test_preprocces(img_size)
    else:
        test_processed = test_preprocces(img_size)

    test_acc = model.evaluate(test_processed)

    # Calculate all relevant metrics
    model_benchmarks['model_name'].append(model_name)
    model_benchmarks['num_model_params'].append(model.count_params())
    model_benchmarks['validation_accuracy'].append(np.mean(all_acc))
    model_benchmarks['test_accuracy'].append(test_acc[-1])
# Out:
#   0%|          | 0/6 [00:00<?, ?it/s]
# ------------------------------------------------------------------------
# Training for fold 1 ...
# Found 125 validated image filenames belonging to 2 classes.
# Found 32 validated image filenames belonging to 2 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 [==============================] - 0s 0us/step
# Epoch 1/5
# 4/4 [==============================] - 48s 8s/step - loss: 0.6904 - accuracy: 0.4960 - val_loss: 0.6815 - val_accuracy: 0.5000
# Epoch 2/5
# 4/4 [==============================] - 2s 565ms/step - loss: 0.6660 - accuracy: 0.6240 - val_loss: 0.6660 - val_accuracy: 0.5312
# Epoch 3/5
# 4/4 [==============================] - 2s 496ms/step - loss: 0.6477 - accuracy: 0.6480 - val_loss: 0.6510 - val_accuracy: 0.6250
# Epoch 4/5
# 4/4 [==============================] - 2s 469ms/step - loss: 0.6409 - accuracy: 0.7040 - val_loss: 0.6430 - val_accuracy: 0.6562
# Epoch 5/5
# 4/4 [==============================] - 2s 462ms/step - loss: 0.6348 - accuracy: 0.6560 - val_loss: 0.6332 - val_accuracy: 0.7188
# Score for fold 1: Loss of 0.6332289576530457; Accuracy of 71.88%
# ------------------------------------------------------------------------
# Training for fold 2 ...
# Found 125 validated image filenames belonging to 2 classes.
# Found 32 validated image filenames belonging to 2 classes.
# Epoch 1/5
# 4/4 [==============================] - 11s 1s/step - loss: 0.6941 - accuracy: 0.5200 - val_loss: 0.6473 - val_accuracy: 0.6562
# Epoch 2/5
# 4/4 [==============================] - 2s 478ms/step - loss: 0.6786 - accuracy: 0.5920 - val_loss: 0.6419 - val_accuracy: 0.7500
# Epoch 3/5
# 4/4 [==============================] - 2s 570ms/step - loss: 0.6665 - accuracy: 0.6320 - val_loss: 0.6355 - val_accuracy: 0.7188
# Epoch 4/5
# 4/4 [==============================] - 2s 584ms/step - loss: 0.6499 - accuracy: 0.6640 - val_loss: 0.6315 - val_accuracy: 0.7812
# Epoch 5/5
# 4/4 [==============================] - 2s 481ms/step - loss: 0.6435 - accuracy: 0.6560 - val_loss: 0.6251 - val_accuracy: 0.8125
# Score for fold 2: Loss of 0.6251353025436401; Accuracy of 81.25%
# ------------------------------------------------------------------------
# Training for fold 3 ...
# Found 126 validated image filenames belonging to 2 classes.
# Found 31 validated image filenames belonging to 2 classes.
# Epoch 1/5
# 4/4 [==============================] - 24s 5s/step - loss: 0.8422 - accuracy: 0.5079 - val_loss: 0.7778 - val_accuracy: 0.4516
# Epoch 2/5
# 4/4 [==============================] - 2s
- val_accuracy: 0.5161
# Epoch 4/5
# 4/4 [==============================] - 2s 425ms/step - loss: 0.7023 - accuracy: 0.4921 - val_loss: 0.6941 - val_accuracy: 0.5161
# Epoch 5/5
# 4/4 [==============================] - 2s 454ms/step - loss: 0.6949 - accuracy: 0.4841 - val_loss: 0.6956 - val_accuracy: 0.4839
# Score for fold 3: Loss of 0.6956232190132141; Accuracy of 48.39%
# ------------------------------------------------------------------------
# Training for fold 4 ...
# Found 126 validated image filenames belonging to 2 classes.
# Found 31 validated image filenames belonging to 2 classes.
# Epoch 1/5
# 4/4 [==============================] - 12s 957ms/step - loss: 0.7014 - accuracy: 0.4921 - val_loss: 0.6930 - val_accuracy: 0.5161
# Epoch 2/5
# 4/4 [==============================] - 2s 432ms/step - loss: 0.7172 - accuracy: 0.5000 - val_loss: 0.7032 - val_accuracy: 0.5161
# Epoch 3/5
# 4/4 [==============================] - 2s 521ms/step - loss: 0.7045 - accuracy: 0.5000 - val_loss: 0.6927 - val_accuracy: 0.5161
# Epoch 4/5
# 4/4 [==============================] - 2s 618ms/step - loss: 0.6987 - accuracy: 0.4524 - val_loss: 0.6988 - val_accuracy: 0.4839
# Epoch 5/5
# 4/4 [==============================] - 2s 390ms/step - loss: 0.6983 - accuracy: 0.4921 - val_loss: 0.7029 - val_accuracy: 0.4839
# Score for fold 4: Loss of 0.7029054760932922; Accuracy of 48.39%
# ------------------------------------------------------------------------
# Training for fold 5 ...
# Found 126 validated image filenames belonging to 2 classes.
# Found 31 validated image filenames belonging to 2 classes.
# Epoch 1/5
# 4/4 [==============================] - 11s 1s/step - loss: 0.7005 - accuracy: 0.5000 - val_loss: 0.6929 - val_accuracy: 0.5161
# Epoch 2/5
# 4/4 [==============================] - 2s 578ms/step - loss: 0.6944 - accuracy: 0.5397 - val_loss: 0.7059 - val_accuracy: 0.4839
# Epoch 3/5
# 4/4 [==============================] - 2s 547ms/step - loss: 0.7005 - accuracy: 0.5000 - val_loss: 0.6973 - val_accuracy: 0.4839
# Epoch 4/5
# 4/4 [==============================] - 2s 440ms/step - loss: 0.7019 - accuracy: 0.4444 - val_loss: 0.6932 - val_accuracy: 0.5161
# Epoch 5/5
# 4/4 [==============================] - 2s 557ms/step - loss: 0.6956 - accuracy: 0.5079 - val_loss: 0.6929 - val_accuracy: 0.5161
# Score for fold 5: Loss of 0.6929261088371277; Accuracy of 51.61%
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - Loss: 0.6952632069587708 - Accuracy: 50.0%
# ------------------------------------------------------------------------
# > Fold 2 - Loss: 0.6935544013977051 - Accuracy: 50.0%
# ------------------------------------------------------------------------
# > Fold 3 - Loss: 0.6956232190132141 - Accuracy: 48.38709533214569%
# ------------------------------------------------------------------------
# > Fold 4 - Loss: 0.7029054760932922 - Accuracy: 48.38709533214569%
# ------------------------------------------------------------------------
# > Fold 5 - Loss: 0.6929261088371277 - Accuracy: 51.61290168762207%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 49.67741847038269 (+- 1.2069863771273763)
# > Loss: 0.696054482460022
# ------------------------------------------------------------------------
# Found 67 images belonging to 2 classes.
# 3/3 [==============================] - 2s 750ms/step - loss: 0.6956 - accuracy: 0.4925
#  33%|███▎      | 2/6 [06:20<11:57, 179.46s/it]
# ------------------------------------------------------------------------
# Training for fold 1 ...
# Found 125 validated image filenames belonging to 2 classes.
# Found 32 validated image filenames belonging to 2 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 [==============================] - 0s 0us/step
# Epoch 1/5
# 4/4 [==============================] - 16s 2s/step - loss: 0.6962 - accuracy: 0.5360 - val_loss: 0.6878 - val_accuracy: 0.5312
# Epoch 2/5
# 4/4 [==============================] - 2s 408ms/step - loss: 0.6638 - accuracy: 0.6080 - val_loss: 0.6396 - val_accuracy: 0.7500
# Epoch 3/5
# 4/4 [==============================] - 2s 438ms/step - loss: 0.6276 - accuracy: 0.6480 - val_loss: 0.6204 - val_accuracy: 0.6875
# Epoch 4/5
# 4/4 [==============================] - 2s 533ms/step - loss: 0.6050 - accuracy: 0.7200 - val_loss: 0.5941 - val_accuracy: 0.7812
# Epoch 5/5
# 4/4 [==============================] - 2s 601ms/step - loss: 0.5694 - accuracy: 0.7840 - val_loss: 0.5718 - val_accuracy: 0.8438
# Score for fold 1: Loss of 0.5718399286270142; Accuracy of 84.38%
# ------------------------------------------------------------------------
# Training for fold 2 ...
# Found 125 validated image filenames belonging to 2 classes.
# Found 32 validated image filenames belonging to 2 classes.
# Epoch 1/5
# 4/4 [==============================] - 10s 1s/step - loss: 0.7224 - accuracy: 0.4720 - val_loss: 0.6622 - val_accuracy: 0.5625
# Epoch 2/5
# 4/4 [==============================] - 2s 485ms/step - loss: 0.6845 - accuracy: 0.6000 - val_loss: 0.6210 - val_accuracy: 0.7188
# Epoch 3/5
# 4/4 [==============================] - 2s 441ms/step - loss: 0.6339 - accuracy: 0.6960 - val_loss: 0.6005 - val_accuracy: 0.7188
# Epoch 4/5
# 4/4 [==============================] - 2s 425ms/step - loss: 0.6056 - accuracy: 0.7200 - val_loss: 0.5811 - val_accuracy: 0.8125
# Epoch 5/5
# 4/4 [==============================] - 2s 430ms/step - loss: 0.5752 - accuracy: 0.7520 - val_loss: 0.5666 - val_accuracy: 0.8438
# Score for fold 2: Loss of 0.5666358470916748; Accuracy of 84.38%
# ------------------------------------------------------------------------
# Training for fold 3 ...
# Found 126 validated image filenames belonging to 2 classes.
# Found 31 validated image filenames belonging to 2 classes.
# Epoch 1/5
# 4/4 [==============================] - 17s 2s/step - loss: 0.8047 - accuracy: 0.4603 - val_loss: 0.7324 - val_accuracy: 0.4839
# Epoch 2/5
# 4/4 [==============================] - 2s 430ms/step - loss: 0.7714 - accuracy: 0.4524 - val_loss: 0.6530 - val_accuracy: 0.7419
# Epoch 3/5
# 4/4 [==============================] - 2s 552ms/step - loss: 0.7096 - accuracy: 0.4762 - val_loss: 0.6399 - val_accuracy: 0.6774
# Epoch 4/5
# 4/4 [==============================] - 2s 619ms/step - loss: 0.6740 - accuracy: 0.5873 - val_loss: 0.6207 - val_accuracy: 0.7742
# Epoch 5/5
# 4/4 [==============================] - 2s 467ms/step - loss: 0.6412 - accuracy: 0.6825 - val_loss: 0.6105 - val_accuracy: 0.7097
# Score for fold 3: Loss of 0.6105080246925354; Accuracy of 70.97%
# ------------------------------------------------------------------------
# Training for fold 4 ...
# Found 126 validated image filenames belonging to 2 classes.
# Found 31 validated image filenames belonging to 2 classes.
# Epoch 1/5
# 4/4 [==============================] - 10s 1s/step - loss: 0.6509 - accuracy: 0.6270 - val_loss: 0.5943 - val_accuracy: 0.7419
# Epoch 2/5
# 4/4 [==============================] - 2s 423ms/step - loss: 0.5996 - accuracy: 0.7540 - val_loss: 0.5624 - val_accuracy: 0.7742
# Epoch 3/5
# 4/4 [==============================] - 2s 429ms/step - loss: 0.5688 - accuracy: 0.7937 - val_loss: 0.5408 - val_accuracy: 0.7419
# Epoch 4/5
# 4/4 [==============================] - 2s 435ms/step - loss: 0.5360 - accuracy: 0.8254 - val_loss: 0.5179 - val_accuracy: 0.8387
# Epoch 5/5
# 4/4 [==============================] - 2s 423ms/step - loss: 0.5169 - accuracy: 0.8175 - val_loss: 0.5005 - val_accuracy: 0.7742
# Score for fold 4: Loss of 0.5005280375480652; Accuracy of 77.42%
# ------------------------------------------------------------------------
# Training for fold 5 ...
# Found 126 validated image filenames belonging to 2 classes.
# Found 31 validated image filenames belonging to 2 classes.
# Epoch 1/5
# 4/4 [==============================] - 8s 890ms/step - loss: 0.7446 - accuracy: 0.4286 - val_loss: 0.7114 - val_accuracy: 0.5484
# Epoch 2/5
# 4/4 [==============================] - 2s 435ms/step - loss: 0.6888 - accuracy: 0.4841 - val_loss: 0.6945 - val_accuracy: 0.6452
# Epoch 3/5
# 4/4 [==============================] - 2s 420ms/step - loss: 0.6494 - accuracy: 0.6349 - val_loss: 0.6733 - val_accuracy: 0.6129
# Epoch 4/5
# 4/4 [==============================] - 2s 498ms/step - loss: 0.6201 - accuracy: 0.7460 - val_loss: 0.6557 - val_accuracy: 0.6129
# Epoch 5/5
# 4/4 [==============================] - 2s 592ms/step - loss: 0.5891 - accuracy: 0.7460 - val_loss: 0.6382 - val_accuracy: 0.6452
# Score for fold 5: Loss of 0.6382445693016052; Accuracy of 64.52%
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - Loss: 0.5718399286270142 - Accuracy: 84.375%
# ------------------------------------------------------------------------
# > Fold 2 - Loss: 0.5666358470916748 - Accuracy: 84.375%
# ------------------------------------------------------------------------
# > Fold 3 - Loss: 0.6105080246925354 - Accuracy: 70.96773982048035%
# ------------------------------------------------------------------------
# > Fold 4 - Loss: 0.5005280375480652 - Accuracy: 77.4193525314331%
# ------------------------------------------------------------------------
# > Fold 5 - Loss: 0.6382445693016052 - Accuracy: 64.51612710952759%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 76.33064389228821 (+- 7.732427352000851)
# > Loss: 0.5775512814521789
# ------------------------------------------------------------------------
# Found 67 images belonging to 2 classes.
# 3/3 [==============================] - 2s 1s/step - loss: 0.6453 - accuracy: 0.6269
#  50%|█████     | 3/6 [08:34<07:55, 158.61s/it]
# ------------------------------------------------------------------------
# Training for fold 1 ...
# Found 125 validated image filenames belonging to 2 classes.
# Found 32 validated image filenames belonging to 2 classes.
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet/mobilenet_1_0_224_tf_no_top.h5
# 17225924/17225924 [==============================] - 0s 0us/step
# Epoch 1/5
# 4/4 [==============================] - 6s 898ms/step - loss: 0.7333 - accuracy: 0.4560 - val_loss: 0.6968 - val_accuracy: 0.5938
# Epoch 2/5
# 4/4 [==============================] - 2s 516ms/step - loss: 0.7086 - accuracy: 0.5120 - val_loss: 0.6632 - val_accuracy: 0.5625
# Epoch 3/5
# 4/4 [==============================] - 2s 427ms/step - loss: 0.6758 - accuracy: 0.5920 - val_loss: 0.6445 - val_accuracy: 0.5625
# Epoch 4/5
# 4/4 [==============================] - 2s 414ms/step - loss: 0.6524 - accuracy: 0.6560 - val_loss: 0.6210 - val_accuracy: 0.7188
# Epoch 5/5
# 4/4 [==============================] - 2s 405ms/step - loss: 0.6330 - accuracy: 0.7200 - val_loss: 0.5997 - val_accuracy: 0.8125
# Score for fold 1: Loss of 0.5997372269630432; Accuracy of 81.25%
# ------------------------------------------------------------------------
# Training for fold 2 ...
# Found 125 validated image filenames belonging to 2 classes.
# Found 32 validated image filenames belonging to 2 classes.
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Epoch 1/5
# 4/4 [==============================] - 5s
Accuracy of 48.39%
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - Loss: 0.6967123746871948 - Accuracy: 50.0%
# ------------------------------------------------------------------------
# > Fold 2 - Loss: 0.6936796307563782 - Accuracy: 50.0%
# ------------------------------------------------------------------------
# > Fold 3 - Loss: 0.6973508596420288 - Accuracy: 48.38709533214569%
# ------------------------------------------------------------------------
# > Fold 4 - Loss: 0.6973154544830322 - Accuracy: 48.38709533214569%
# ------------------------------------------------------------------------
# > Fold 5 - Loss: 0.6973933577537537 - Accuracy: 48.38709533214569%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 49.032257199287415 (+- 0.7901586879992478)
# > Loss: 0.6964903354644776
# ------------------------------------------------------------------------
# Found 67 images belonging to 2 classes.
# 3/3 [==============================] - 2s 665ms/step - loss: 0.6917 - accuracy: 0.5075
# 100%|██████████| 6/6 [14:00<00:00, 140.14s/it]

# %%
for model_name, model_1 in tqdm(list(new_model_dict.items())[6:]):
    # Special handling for "NASNetLarge" since it requires input images with size (331,331)

    fold_no = 1
    all_acc = []
    all_loss = []

    for train_indices, val_indices in kfold.split(all_files,labels):
        print('------------------------------------------------------------------------')
        print(f'Training for fold {fold_no} ...')

    # Preprocess data and build model (assuming these functions are defined)
        train_files = [all_files[i] for i in train_indices]
        val_files = [all_files[i] for i in val_indices]
        if 'NASNetLarge' in model_name:
          img_size =(331,331)
          input_shape =(331,331,3)
          train_gen, val_gen = preprocess_data_for_fold(train_files, val_files, img_size)
        elif 'InceptionResNetV2' or 'InceptionV3' or 'Xception' in model_name:
          img_size=(299,299)
          input_shape=(299,299,3)
          train_gen, val_gen = preprocess_data_for_fold(train_files, val_files, img_size)
        else:
          img_size=(224,224)
          input_shape=(224,224,3)
          train_gen, val_gen = preprocess_data_for_fold(train_files, val_files, img_size)


        model = build_model(model_1,input_shape)

    # Fit data to model
        history = model.fit(train_gen, epochs=5, validation_data=val_gen)

    # Evaluate the model on validation set
        scores = model.evaluate(val_gen, verbose=0)
        fold_val_accuracy = round(scores[1] * 100, 2)
        print(f'Score for fold {fold_no}: Loss of {scores[0]}; Accuracy of {fold_val_accuracy}%')
        all_acc.append(fold_val_accuracy)
        all_loss.append(scores[0])

    # Increase fold number
        fold_no += 1

# Provide average scores
    print('------------------------------------------------------------------------')
    print('Score per fold')
    for i in range(len(all_acc)):
        print('------------------------------------------------------------------------')
        print(f'> Fold {i+1} - Loss: {all_loss[i]} - Accuracy: {all_acc[i]}%')
    print('------------------------------------------------------------------------')
    print('Average scores for all folds:')
    print(f'> Accuracy: {np.mean(all_acc)} (+- {np.std(all_acc)})')
    print(f'> Loss: {np.mean(all_loss)}')
    print('------------------------------------------------------------------------')
    if 'NASNetLarge' in model_name:
        test_processed = test_preprocces(img_size)
    elif 'InceptionResNetV2' or 'InceptionV3' or 'Xception' in model_name:
        test_processed = test_preprocces(img_size)
    else:
        test_processed = test_preprocces(img_size)

    test_acc = model.evaluate(test_processed)

    # Calculate all relevant metrics
    model_benchmarks['model_name'].append(model_name)
    model_benchmarks['num_model_params'].append(model.count_params())
    model_benchmarks['validation_accuracy'].append(np.mean(all_acc))
    model_benchmarks['test_accuracy'].append(test_acc[-1])
# Out:
#   0%|          | 0/6 [00:00<?, ?it/s]
# ------------------------------------------------------------------------
# Training for fold 1 ...
# Found 125 validated image filenames belonging to 2 classes.
# Found 32 validated image filenames belonging to 2 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet101v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 171317808/171317808 [==============================] - 1s 0us/step
# Epoch 1/5
# 4/4 [==============================] - 14s 2s/step - loss: 0.7337 - accuracy: 0.5280 - val_loss: 0.7228 - val_accuracy: 0.5000
# Epoch 2/5
# 4/4 [==============================] - 2s 492ms/step - loss: 0.6960 - accuracy: 0.5600 - val_loss: 0.6618 - val_accuracy: 0.5938
# Epoch 3/5
# 4/4 [==============================] - 2s 486ms/step - loss: 0.6405 - accuracy: 0.6320 - val_loss: 0.6379 - val_accuracy: 0.7188
# Epoch 4/5
# 4/4 [==============================] - 2s 466ms/step - loss: 0.6207 - accuracy: 0.6560 - val_loss: 0.6084 - val_accuracy: 0.7500
# Epoch 5/5
# 4/4 [==============================] - 2s 585ms/step - loss: 0.5873 - accuracy: 0.7680 - val_loss: 0.5954 - val_accuracy: 0.7500
# Score for fold 1: Loss of 0.5953896641731262; Accuracy of 75.0%
# ------------------------------------------------------------------------
# Training for fold 2 ...
# Found 125 validated image filenames belonging to 2 classes.
# Found 32 validated image filenames belonging to 2 classes.
# Epoch 1/5
# 4/4 [==============================] - 11s 1s/step - loss: 0.7757 - accuracy: 0.4400 - val_loss: 0.7861 - val_accuracy: 0.4688
# Epoch 2/5
# 4/4 [==============================] - 2s 495ms/step - loss: 0.7348 - accuracy: 0.4960 - val_loss: 0.7268 - val_accuracy: 0.4688
# Epoch 3/5
# 4/4 [==============================] - 2s 529ms/step - loss: 0.6697 - accuracy: 0.6000 - val_loss: 0.7252 - val_accuracy: 0.5000
# Epoch 4/5
# 4/4 [==============================] - 2s
0%
# ------------------------------------------------------------------------
# Training for fold 2 ...
# Found 125 validated image filenames belonging to 2 classes.
# Found 32 validated image filenames belonging to 2 classes.
# Epoch 1/5
# 4/4 [==============================] - 6s 769ms/step - loss: 0.6403 - accuracy: 0.6240 - val_loss: 0.6394 - val_accuracy: 0.6875
# Epoch 2/5
# 4/4 [==============================] - 2s 458ms/step - loss: 0.6017 - accuracy: 0.6560 - val_loss: 0.5946 - val_accuracy: 0.6562
# Epoch 3/5
# 4/4 [==============================] - 2s 503ms/step - loss: 0.5573 - accuracy: 0.7680 - val_loss: 0.5742 - val_accuracy: 0.6875
# Epoch 4/5
# 4/4 [==============================] - 2s 547ms/step - loss: 0.5216 - accuracy: 0.8160 - val_loss: 0.5541 - val_accuracy: 0.8125
# Epoch 5/5
# 4/4 [==============================] - 2s 466ms/step - loss: 0.4970 - accuracy: 0.8080 - val_loss: 0.5407 - val_accuracy: 0.8125
# Score for fold 2: Loss of 0.5406795144081116; Accuracy of 81.25%
# ------------------------------------------------------------------------
# Training for fold 3 ...
# Found 126 validated image filenames belonging to 2 classes.
# Found 31 validated image filenames belonging to 2 classes.
# Epoch 1/5
# 4/4 [==============================] - 6s 934ms/step - loss: 0.7368 - accuracy: 0.5317 - val_loss: 0.6661 - val_accuracy: 0.6774
# Epoch 2/5
# 4/4 [==============================] - 2s 593ms/step - loss: 0.6546 - accuracy: 0.6349 - val_loss: 0.6531 - val_accuracy: 0.6129
# Epoch 3/5
# 4/4 [==============================] - 2s 446ms/step - loss: 0.6164 - accuracy: 0.7143 - val_loss: 0.6652 - val_accuracy: 0.5161
# Epoch 4/5
# 4/4 [==============================] - 2s 428ms/step - loss: 0.5789 - accuracy: 0.7540 - val_loss: 0.6387 - val_accuracy: 0.6452
# Epoch 5/5
# 4/4 [==============================] - 2s 436ms/step - loss: 0.5344 - accuracy: 0.8413 - val_loss: 0.6283 - val_accuracy: 0.6774
# Score for fold 3: Loss of 0.6283404231071472; Accuracy of 67.74%
# ------------------------------------------------------------------------
# Training for fold 4 ...
# Found 126 validated image filenames belonging to 2 classes.
# Found 31 validated image filenames belonging to 2 classes.
# Epoch 1/5
# 4/4 [==============================] - 9s 808ms/step - loss: 0.8045 - accuracy: 0.4603 - val_loss: 0.6558 - val_accuracy: 0.6129
# Epoch 2/5
# 4/4 [==============================] - 2s 456ms/step - loss: 0.7044 - accuracy: 0.5159 - val_loss: 0.6506 - val_accuracy: 0.5484
# Epoch 3/5
# 4/4 [==============================] - 2s 543ms/step - loss: 0.6591 - accuracy: 0.5952 - val_loss: 0.5925 - val_accuracy: 0.7742
# Epoch 4/5
# 4/4 [==============================] - 2s 619ms/step - loss: 0.6296 - accuracy: 0.6667 - val_loss: 0.5772 - val_accuracy: 0.7419
# Epoch 5/5
# 4/4 [==============================] - 3s 655ms/step - loss: 0.6028 - accuracy: 0.7063 - val_loss: 0.5479 - val_accuracy: 0.8387
# Score for fold 4: Loss of 0.5479068160057068; Accuracy of 83.87%
# ------------------------------------------------------------------------
# Training for fold 5 ...
# Found 126 validated image filenames belonging to 2 classes.
# Found 31 validated image filenames belonging to 2 classes.
# Epoch 1/5
# 4/4 [==============================] - 6s 764ms/step - loss: 0.7514 - accuracy: 0.3730 - val_loss: 0.7295 - val_accuracy: 0.4516
# Epoch 2/5
# 4/4 [==============================] - 2s 433ms/step - loss: 0.6878 - accuracy: 0.5635 - val_loss: 0.6853 - val_accuracy: 0.5806
# Epoch 3/5
# 4/4 [==============================] - 2s 533ms/step - loss: 0.6375 - accuracy: 0.6825 - val_loss: 0.6414 - val_accuracy: 0.6129
# Epoch 4/5
# 4/4 [==============================] - 2s 532ms/step - loss: 0.5905 - accuracy: 0.7778 - val_loss: 0.6089 - val_accuracy: 0.8065
# Epoch 5/5
# 4/4 [==============================] - 2s 506ms/step - loss: 0.5584 - accuracy: 0.8333 - val_loss: 0.5768 - val_accuracy: 0.8065
# Score for fold 5: Loss of 0.5768182277679443; Accuracy of 80.65%
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - Loss: 0.4867655038833618 - Accuracy: 75.0%
# ------------------------------------------------------------------------
# > Fold 2 - Loss: 0.5406795144081116 - Accuracy: 81.25%
# ------------------------------------------------------------------------
# > Fold 3 - Loss: 0.6283404231071472 - Accuracy: 67.74%
# ------------------------------------------------------------------------
# > Fold 4 - Loss: 0.5479068160057068 - Accuracy: 83.87%
# ------------------------------------------------------------------------
# > Fold 5 - Loss: 0.5768182277679443 - Accuracy: 80.65%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 77.702 (+- 5.759609014507846)
# > Loss: 0.5561020970344543
# ------------------------------------------------------------------------
# Found 67 images belonging to 2 classes.
# 3/3 [==============================] - 1s 172ms/step - loss: 0.6029 - accuracy: 0.7164
#  50%|█████     | 3/6 [05:39<05:26, 108.95s/it]
# ------------------------------------------------------------------------
# Training for fold 1 ...
# Found 125 validated image filenames belonging to 2 classes.
# Found 32 validated image filenames belonging to 2 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 0s 0us/step
# Epoch 1/5
# 4/4 [==============================] -
Accuracy of 48.39%
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - Loss: 0.7033820152282715 - Accuracy: 50.0%
# ------------------------------------------------------------------------
# > Fold 2 - Loss: 0.6991927623748779 - Accuracy: 50.0%
# ------------------------------------------------------------------------
# > Fold 3 - Loss: 0.6976317167282104 - Accuracy: 51.61%
# ------------------------------------------------------------------------
# > Fold 4 - Loss: 0.6754099726676941 - Accuracy: 70.97%
# ------------------------------------------------------------------------
# > Fold 5 - Loss: 0.6959307789802551 - Accuracy: 48.39%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 54.194 (+- 8.449578924419843)
# > Loss: 0.6943094491958618
# ------------------------------------------------------------------------
# Found 67 images belonging to 2 classes.
# 3/3 [==============================] - 1s 195ms/step - loss: 0.6852 - accuracy: 0.5075
#  83%|████████▎ | 5/6 [08:48<01:39, 99.14s/it]
# ------------------------------------------------------------------------
# Training for fold 1 ...
# Found 125 validated image filenames belonging to 2 classes.
# Found 32 validated image filenames belonging to 2 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 [==============================] - 0s 0us/step
# Epoch 1/5
# 4/4 [==============================] - 14s 2s/step - loss: 0.6853 - accuracy: 0.5120 - val_loss: 0.6313 - val_accuracy: 0.7188
# Epoch 2/5
# 4/4 [==============================] - 2s 482ms/step - loss: 0.6577 - accuracy: 0.6080 - val_loss: 0.6035 - val_accuracy: 0.8750
# Epoch 3/5
# 4/4 [==============================] - 2s 466ms/step - loss: 0.6356 - accuracy: 0.6960 - val_loss: 0.5801 - val_accuracy: 0.8438
# Epoch 4/5
# 4/4 [==============================] - 2s 491ms/step - loss: 0.6284 - accuracy: 0.6960 - val_loss: 0.5624 - val_accuracy: 0.7500
# Epoch 5/5
# 4/4 [==============================] - 2s 592ms/step - loss: 0.6068 - accuracy: 0.7200 - val_loss: 0.5375 - val_accuracy: 0.8750
# Score for fold 1: Loss of 0.5374925136566162; Accuracy of 87.5%
# ------------------------------------------------------------------------
# Training for fold 2 ...
# Found 125 validated image filenames belonging to 2 classes.
# Found 32 validated image filenames belonging to 2 classes.
# Epoch 1/5
# 4/4 [==============================] - 5s 789ms/step - loss: 0.7011 - accuracy: 0.5280 - val_loss: 0.6691 - val_accuracy: 0.5000
# Epoch 2/5
# 4/4 [==============================] - 2s 463ms/step - loss: 0.6607 - accuracy: 0.7040 - val_loss: 0.6461 - val_accuracy: 0.6250
# Epoch 3/5
# 4/4 [==============================] - 2s 619ms/step - loss: 0.6395 - accuracy: 0.6880 - val_loss: 0.6329 - val_accuracy: 0.6875
# Epoch 4/5
# 4/4 [==============================] - 2s 530ms/step - loss: 0.6186 - accuracy: 0.7120 - val_loss: 0.6151 - val_accuracy: 0.6562
# Epoch 5/5
# 4/4 [==============================] - 2s 483ms/step - loss: 0.5923 - accuracy: 0.7920 - val_loss: 0.5962 - val_accuracy: 0.7500
# Score for fold 2: Loss of 0.5961785316467285; Accuracy of 75.0%
# ------------------------------------------------------------------------
# Training for fold 3 ...
# Found 126 validated image filenames belonging to 2 classes.
# Found 31 validated image filenames belonging to 2 classes.
# Epoch 1/5
# 4/4 [==============================] - 14s 2s/step - loss: 0.6811 - accuracy: 0.5397 - val_loss: 0.6921 - val_accuracy: 0.5484
# Epoch 2/5
# 4/4 [==============================] - 2s 482ms/step - loss: 0.6426 - accuracy: 0.7143 - val_loss: 0.6836 - val_accuracy: 0.6774
# Epoch 3/5
# 4/4 [==============================] - 2s 475ms/step - loss: 0.6132 - accuracy: 0.7619 - val_loss: 0.6715 - val_accuracy: 0.6774
# Epoch 4/5
# 4/4 [==============================] - 2s 550ms/step - loss: 0.5853 - accuracy: 0.7857 - val_loss: 0.6613 - val_accuracy: 0.6774
# Epoch 5/5
# 4/4 [==============================] - 2s 604ms/step - loss: 0.5604 - accuracy: 0.7698 - val_loss: 0.6534 - val_accuracy: 0.6774
# Score for fold 3: Loss of 0.6534340381622314; Accuracy of 67.74%
# ------------------------------------------------------------------------
# Training for fold 4 ...
# Found 126 validated image filenames belonging to 2 classes.
# Found 31 validated image filenames belonging to 2 classes.
# Epoch 1/5
# 4/4 [==============================] - 7s 771ms/step - loss: 0.6959 - accuracy: 0.5079 - val_loss: 0.6611 - val_accuracy: 0.6774
# Epoch 2/5
# 4/4 [==============================] - 2s 563ms/step - loss: 0.6519 - accuracy: 0.6508 - val_loss: 0.6367 - val_accuracy: 0.6129
# Epoch 3/5
# 4/4 [==============================] - 2s 550ms/step - loss: 0.6297 - accuracy: 0.7540 - val_loss: 0.6185 - val_accuracy: 0.6452
# Epoch 4/5
# 4/4 [==============================] - 2s 467ms/step - loss: 0.6048 - accuracy: 0.7778 - val_loss: 0.6021 - val_accuracy: 0.8065
# Epoch 5/5
# 4/4 [==============================] - 2s 459ms/step - loss: 0.5822 - accuracy: 0.7937 - val_loss: 0.5886 - val_accuracy: 0.7419
# Score for fold 4: Loss of 0.5886496305465698; Accuracy of 74.19%
# ------------------------------------------------------------------------
# Training for fold 5 ...
# Found 126 validated image filenames belonging to 2 classes.
# Found 31 validated image filenames belonging to 2 classes.
# Epoch 1/5
# 4/4 [==============================] - 6s 1s/step - loss: 0.7064 - accuracy: 0.4921 - val_loss: 0.6468 - val_accuracy: 0.7097
# Epoch 2/5
# 4/4 [==============================] - 2s 484ms/step - loss: 0.6681 - accuracy: 0.6825 - val_loss: 0.6299 - val_accuracy: 0.8065
# Epoch 3/5
# 4/4 [==============================] - 2s 463ms/step - loss: 0.6459 - accuracy: 0.6984 - val_loss: 0.6167 - val_accuracy: 0.7097
# Epoch 4/5
# 4/4 [==============================] - 2s 492ms/step - loss: 0.6174 - accuracy: 0.7698 - val_loss: 0.6034 - val_accuracy: 0.7419
# Epoch 5/5
# 4/4 [==============================] - 2s 479ms/step - loss: 0.5979 - accuracy: 0.7857 - val_loss: 0.5938 - val_accuracy: 0.7742
# Score for fold 5: Loss of 0.5937658548355103; Accuracy of 77.42%
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - Loss: 0.5374925136566162 - Accuracy: 87.5%
# ------------------------------------------------------------------------
# > Fold 2 - Loss: 0.5961785316467285 - Accuracy: 75.0%
# ------------------------------------------------------------------------
# > Fold 3 - Loss: 0.6534340381622314 - Accuracy: 67.74%
# ------------------------------------------------------------------------
# > Fold 4 - Loss: 0.5886496305465698 - Accuracy: 74.19%
# ------------------------------------------------------------------------
# > Fold 5 - Loss: 0.5937658548355103 - Accuracy: 77.42%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 76.37 (+- 6.420056074521469)
# > Loss: 0.5939041137695312
# ------------------------------------------------------------------------
# Found 67 images belonging to 2 classes.
# 3/3 [==============================] - 2s 847ms/step - loss: 0.6235 - accuracy: 0.7313
# 100%|██████████| 6/6 [10:39<00:00, 106.52s/it]

# %%
# Convert Results to DataFrame for easy viewing
benchmark_df = pd.DataFrame(model_benchmarks)
benchmark_df.sort_values('num_model_params', inplace=True) # sort in ascending order of num_model_params column
benchmark_df
# Out:
#         model_name  num_model_params  validation_accuracy  test_accuracy
# 4      MobileNetV2           2259265            63.084677       0.537313
# 3        MobileNet           3229889            67.419355       0.761194
# 1   EfficientNetB0           4050852            49.677418       0.492537
# 0      DenseNet121           7038529            60.947580       0.671642
# 9            VGG16          14715201            58.668000       0.597015
# 10           VGG19          20024897            54.194000       0.507463
# 11        Xception          20863529            76.370000       0.731343
# 2      InceptionV3          21804833            76.330644       0.626866
# 8       ResNet50V2          23566849            77.702000       0.716418
# 7         ResNet50          23589761            50.966000       0.492537
# 6      ResNet101V2          42628609            61.088000       0.686567
# 5        ResNet101          42660225            49.032257       0.507463

# %%
markers=[".",",","o","v","^","<",">","1","2","3","4","8","s"]

# %%
len(markers)
# Out:
# 13

# %%
plt.figure(figsize=(7,5))
for row in benchmark_df.itertuples():
    plt.scatter(row.num_model_params, row.validation_accuracy, label=row.model_name, marker=markers[row.Index], s=150, linewidths=2)
plt.xscale('log')
plt.xlabel('Number of Parameters in Model')
plt.ylabel('Cross validation Accuracy after 5 Epochs')
plt.title('Cross validation Accuracy vs Model Size')
plt.legend(bbox_to_anchor=(1, 1), loc='upper left'); # Move legend out of the plot

# %%
plt.figure(figsize=(7,5))
for row in benchmark_df.itertuples():
    plt.scatter(row.num_model_params, row.test_accuracy, label=row.model_name, marker=markers[row.Index], s=150, linewidths=2)
plt.xscale('log')
plt.xlabel('Number of Parameters in Model')
plt.ylabel('Test Accuracy after 5 Epochs')
plt.title('Test Accuracy vs Model Size')
plt.legend(bbox_to_anchor=(1, 1), loc='upper left'); # Move legend out of the plot
