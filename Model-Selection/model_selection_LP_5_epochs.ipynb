# %% [markdown]
# <h1>Comparison of Transfer Learning Models - Lateral View </h1>
#
# <hr>
#
# <p>Within TensorFlow, there are 71 architectures available for Transfer Learning. From these, we have selected 12 for evaluation, testing each over the course of just 5 epochs. We plot a graph to illustrate the relationship between accuracy and the number of parameters within each model. Our objective is to identify a model that minimizes the number of parameters required, while simultaneously maximizing accuracy. It's important to note that, at present, we are not employing any form of data augmentations.</p>

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import inspect
import glob
import os
import matplotlib.image as mpimg
import numpy as np
import seaborn as sns
import pandas as pd
import inspect
from tqdm import tqdm
from keras.preprocessing import image
from sklearn import metrics
from sklearn.metrics import ConfusionMatrixDisplay
from google.colab import drive

from sklearn.model_selection import StratifiedKFold

# %%
from keras.preprocessing import image

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
batch_size = 32
data_path = "/content/drive/MyDrive/sve_LP-bez augumentacije/train"
n_folds =5
kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
all_files = glob.glob(os.path.join(data_path, '*/*'))
labels = [os.path.basename(os.path.dirname(fp)) for fp in all_files]

# %%
# List all available models
model_dictionary = {m[0]:m[1] for m in inspect.getmembers(tf.keras.applications, inspect.isfunction)}

# %%
len(model_dictionary)
# Out:
# 71

# %%
new_model_dict = {key: model_dictionary[key] for key in model_dictionary  if key in ['MobileNetV2', 'MobileNet', 'EfficientNetB0', 'DenseNet121','VGG16', 'VGG19', 'Xception', 'InceptionV3','ResNet50V2','ResNet50', 'ResNet101V2', 'ResNet101']}

# %%
len(new_model_dict)
# Out:
# 12

# %%
def preprocess_data_for_fold(train_files, val_files, img_size):
    #datagen = image.ImageDataGenerator(rescale=1./255., rotation_range=15, brightness_range=[0.2, 1.0])
    datagen = image.ImageDataGenerator(rescale=1./255.)

    # Extracting the labels from the directory structure
    train_labels = [os.path.basename(os.path.dirname(fp)) for fp in train_files]
    val_labels = [os.path.basename(os.path.dirname(fp)) for fp in val_files]

    train_gen = datagen.flow_from_dataframe(
        dataframe=pd.DataFrame({'filename': train_files, 'class': train_labels}),
        directory=None,
        x_col="filename",
        y_col="class",
        class_mode="binary",
        target_size=img_size,
        batch_size=batch_size,
        shuffle=True
    )

    val_gen = datagen.flow_from_dataframe(
        dataframe=pd.DataFrame({'filename': val_files, 'class': val_labels}),
        directory=None,
        x_col="filename",
        y_col="class",
        class_mode="binary",
        target_size=img_size,
        batch_size=batch_size,
        shuffle=False
    )

    return train_gen, val_gen

# %%
def test_preprocces(img_size):
  test_datagen = image.ImageDataGenerator(rescale=1./255.)
  test_generator = test_datagen.flow_from_directory("/content/drive/MyDrive/sve_LP-bez augumentacije/test",
                                        target_size=img_size,
                                        class_mode='binary',
                                        batch_size=batch_size,
                                        shuffle=False)
  return test_generator

# %%
def build_model(model_1,input_shape):
    pre_trained_model = model_1(include_top=False, pooling='avg', input_shape=input_shape)
    pre_trained_model.trainable = False

    model = tf.keras.models.Sequential()
    model.add(pre_trained_model)
    model.add(tf.keras.layers.Dense(1, activation='sigmoid'))
    model.compile(optimizer='adam',loss='binary_crossentropy', metrics=['accuracy'])
    return model

# %%
# Loop over each model available in Keras
model_benchmarks = {'model_name': [], 'num_model_params': [], 'validation_accuracy': [], 'test_accuracy': []}
for model_name, model_1 in tqdm(list(new_model_dict.items())[:6]):
    # Special handling for "NASNetLarge" since it requires input images with size (331,331)

    fold_no = 1
    all_acc = []
    all_loss = []

    for train_indices, val_indices in kfold.split(all_files,labels):
        print('------------------------------------------------------------------------')
        print(f'Training for fold {fold_no} ...')

    # Preprocess data and build model (assuming these functions are defined)
        train_files = [all_files[i] for i in train_indices]
        val_files = [all_files[i] for i in val_indices]
        if 'NASNetLarge' in model_name:
          img_size =(331,331)
          input_shape =(331,331,3)
          train_gen, val_gen = preprocess_data_for_fold(train_files, val_files, img_size)
        elif 'InceptionResNetV2' or 'InceptionV3' or 'Xception' in model_name:
          img_size=(299,299)
          input_shape=(299,299,3)
          train_gen, val_gen = preprocess_data_for_fold(train_files, val_files, img_size)
        else:
          img_size=(224,224)
          input_shape=(224,224,3)
          train_gen, val_gen = preprocess_data_for_fold(train_files, val_files, img_size)


        model = build_model(model_1,input_shape)

    # Fit data to model
        history = model.fit(train_gen, epochs=5, validation_data=val_gen)

    # Evaluate the model on validation set
        scores = model.evaluate(val_gen, verbose=0)
        print(f'Score for fold {fold_no}: Loss of {scores[0]}; Accuracy of {round(scores[1]*100, 2)}%')
        all_acc.append(scores[1] * 100)
        all_loss.append(scores[0])

    # Increase fold number
        fold_no += 1

# Provide average scores
    print('------------------------------------------------------------------------')
    print('Score per fold')
    for i in range(len(all_acc)):
        print('------------------------------------------------------------------------')
        print(f'> Fold {i+1} - Loss: {all_loss[i]} - Accuracy: {all_acc[i]}%')
    print('------------------------------------------------------------------------')
    print('Average scores for all folds:')
    print(f'> Accuracy: {np.mean(all_acc)} (+- {np.std(all_acc)})')
    print(f'> Loss: {np.mean(all_loss)}')
    print('------------------------------------------------------------------------')
    if 'NASNetLarge' in model_name:
        test_processed = test_preprocces(img_size)
    elif 'InceptionResNetV2' or 'InceptionV3' or 'Xception' in model_name:
        test_processed = test_preprocces(img_size)
    else:
        test_processed = test_preprocces(img_size)

    test_acc = model.evaluate(test_processed)

    # Calculate all relevant metrics
    model_benchmarks['model_name'].append(model_name)
    model_benchmarks['num_model_params'].append(model.count_params())
    model_benchmarks['validation_accuracy'].append(np.mean(all_acc))
    model_benchmarks['test_accuracy'].append(test_acc[-1])
# Out:
#   0%|          | 0/6 [00:00<?, ?it/s]
# ------------------------------------------------------------------------
# Training for fold 1 ...
# Found 125 validated image filenames belonging to 2 classes.
# Found 32 validated image filenames belonging to 2 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 [==============================] - 0s 0us/step
# Epoch 1/5
# 4/4 [==============================] - 57s 10s/step - loss: 0.7456 - accuracy: 0.4720 - val_loss: 0.7202 - val_accuracy: 0.4375
# Epoch 2/5
# 4/4 [==============================] - 2s 475ms/step - loss: 0.7089 - accuracy: 0.4880 - val_loss: 0.7160 - val_accuracy: 0.5000
# Epoch 3/5
# 4/4 [==============================] - 2s 608ms/step - loss: 0.6964 - accuracy: 0.5520 - val_loss: 0.7033 - val_accuracy: 0.4688
# Epoch 4/5
# 4/4 [==============================] - 2s 614ms/step - loss: 0.6875 - accuracy: 0.5600 - val_loss: 0.6965 - val_accuracy: 0.5000
# Epoch 5/5
# 4/4 [==============================] - 2s 485ms/step - loss: 0.6772 - accuracy: 0.5680 - val_loss: 0.6884 - val_accuracy: 0.5000
# Score for fold 1: Loss of 0.6883566379547119; Accuracy of 50.0%
# ------------------------------------------------------------------------
# Training for fold 2 ...
# Found 125 validated image filenames belonging to 2 classes.
# Found 32 validated image filenames belonging to 2 classes.
# Epoch 1/5
# 4/4 [==============================] - 11s 1s/step - loss: 0.7689 - accuracy: 0.4080 - val_loss: 0.7402 - val_accuracy: 0.4062
# Epoch 2/5
# 4/4 [==============================] - 2s 474ms/step - loss: 0.7476 - accuracy: 0.4320 - val_loss: 0.7183 - val_accuracy: 0.4688
# Epoch 3/5
# 4/4 [==============================] - 2s 519ms/step - loss: 0.7279 - accuracy: 0.4080 - val_loss: 0.7098 - val_accuracy: 0.5625
# Epoch 4/5
# 4/4 [==============================] - 2s 502ms/step - loss: 0.7217 - accuracy: 0.4400 - val_loss: 0.7009 - val_accuracy: 0.5000
# Epoch 5/5
# 4/4 [==============================] - 3s 909ms/step - loss: 0.7052 - accuracy: 0.4960 - val_loss: 0.6838 - val_accuracy: 0.6250
# Score for fold 2: Loss of 0.6838427782058716; Accuracy of 62.5%
# ------------------------------------------------------------------------
# Training for fold 3 ...
# Found 126 validated image filenames belonging to 2 classes.
# Found 31 validated image filenames belonging to 2 classes.
# Epoch 1/5
# 4/4 [==============================] - 26s 4s/step - loss: 0.7819 - accuracy: 0.4048 - val_loss: 0.7592 - val_accuracy: 0.4839
# Epoch 2/5
# 4/4 [==============================] - 2s 479ms/step - loss: 0.7507 - accuracy: 0.4206 - val_loss: 0.7403 - val_accuracy: 0.4516
# Epoch 3/5
# 4/4 [==============================] - 2s 474ms/step - loss: 0.7331 - accuracy: 0.4365 - val_loss: 0.7387 - val_accuracy: 0.4194
# Epoch 4/5
# 4/4 [==============================] - 2s 475ms/step - loss: 0.7262 - accuracy: 0.4841 - val_loss: 0.7258 - val_accuracy: 0.4839
# Epoch 5/5
# 4/4 [==============================] - 2s 475ms/step - loss: 0.7134 - accuracy: 0.5159 - val_loss: 0.7144 - val_accuracy: 0.5484
# Score for fold 3: Loss of 0.7144297957420349; Accuracy of 54.84%
# ------------------------------------------------------------------------
# Training for fold 4 ...
# Found 126 validated image filenames belonging to 2 classes.
# Found 31 validated image filenames belonging to 2 classes.
# Epoch 1/5
# 4/4 [==============================] - 11s 1s/step - loss: 0.7397 - accuracy: 0.4762 - val_loss: 0.7006 - val_accuracy: 0.5161
# Epoch 2/5
# 4/4 [==============================] - 2s 585ms/step - loss: 0.6999 - accuracy: 0.4524 - val_loss: 0.6978 - val_accuracy: 0.4839
# Epoch 3/5
# 4/4 [==============================] - 2s 488ms/step - loss: 0.6937 - accuracy: 0.5159 - val_loss: 0.6914 - val_accuracy: 0.4516
# Epoch 4/5
# 4/4 [==============================] - 2s 490ms/step - loss: 0.6838 - accuracy: 0.5317 - val_loss: 0.6867 - val_accuracy: 0.5161
# Epoch 5/5
# 4/4 [==============================] - 2s 474ms/step - loss: 0.6723 - accuracy: 0.5556 - val_loss: 0.6842 - val_accuracy: 0.5484
# Score for fold 4: Loss of 0.6841817498207092; Accuracy of 54.84%
# ------------------------------------------------------------------------
# Training for fold 5 ...
# Found 126 validated image filenames belonging to 2 classes.
# Found 31 validated image filenames belonging to 2 classes.
# Epoch 1/5
# 4/4 [==============================] - 10s 1s/step - loss: 0.9306 - accuracy: 0.4921 - val_loss: 0.7944 - val_accuracy: 0.5161
# Epoch 2/5
# 4/4 [==============================] - 2s 512ms/step - loss: 0.7121 - accuracy: 0.5159 - val_loss: 0.7656 - val_accuracy: 0.4194
# Epoch 3/5
# 4/4 [==============================] - 2s 635ms/step - loss: 0.7357 - accuracy: 0.4921 - val_loss: 0.8190 - val_accuracy: 0.4839
# Epoch 4/5
# 4/4 [==============================] - 2s 527ms/step - loss: 0.7399 - accuracy: 0.5079 - val_loss: 0.7800 - val_accuracy: 0.4839
# Epoch 5/5
# 4/4 [==============================] - 2s 465ms/step - loss: 0.6941 - accuracy: 0.5317 - val_loss: 0.7366 - val_accuracy: 0.3548
# Score for fold 5: Loss of 0.7366365194320679; Accuracy of 35.48%
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - Loss: 0.6883566379547119 - Accuracy: 50.0%
# ------------------------------------------------------------------------
# > Fold 2 - Loss: 0.6838427782058716 - Accuracy: 62.5%
# ------------------------------------------------------------------------
# > Fold 3 - Loss: 0.7144297957420349 - Accuracy: 54.83871102333069%
# ------------------------------------------------------------------------
# > Fold 4 - Loss: 0.6841817498207092 - Accuracy: 54.83871102333069%
# ------------------------------------------------------------------------
# > Fold 5 - Loss: 0.7366365194320679 - Accuracy: 35.48386991024017%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 51.53225839138031 (+- 8.967220334391897)
# > Loss: 0.7014894962310791
# ------------------------------------------------------------------------
# Found 67 images belonging to 2 classes.
# 3/3 [==============================] - 16s 8s/step - loss: 0.6880 - accuracy: 0.5522
#  17%|█▋        | 1/6 [04:00<20:01, 240.21s/it]
# ------------------------------------------------------------------------
# Training for fold 1 ...
# Found 125 validated image filenames belonging to 2 classes.
# Found 32 validated image filenames belonging to 2 classes.
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 [==============================] - 0s 0us/step
# Epoch 1/5
# 4/4 [==============================] - 14s 2s/step - loss: 0.6995 - accuracy: 0.4080 - val_loss: 0.6933 - val_accuracy: 0.5000
# Epoch 2/5
# 4/4 [==============================] - 2s 442ms/step - loss: 0.6951 - accuracy: 0.4320 - val_loss: 0.6941 - val_accuracy: 0.5000
# Epoch 3/5
# 4/4 [==============================] - 2s 433ms/step - loss: 0.6952 - accuracy: 0.5040 - val_loss: 0.6968 - val_accuracy: 0.5000
# Epoch 4/5
# 4/4 [==============================] - 2s 442ms/step - loss: 0.7040 - accuracy: 0.4560 - val_loss: 0.6934 - val_accuracy: 0.5000
# Epoch 5/5
# 4/4 [==============================] - 2s 430ms/step - loss: 0.6933 - accuracy: 0.5280 - val_loss: 0.6932 - val_accuracy: 0.5000
# Score for fold 1: Loss of 0.6931803822517395; Accuracy of 50.0%
# ------------------------------------------------------------------------
# Training for fold 2 ...
# Found 125 validated image filenames belonging to 2 classes.
# Found 32 validated image filenames belonging to 2 classes.
# Epoch 1/5
# 4/4 [==============================] - 10s 962ms/step - loss: 0.6970 - accuracy: 0.5360 - val_loss: 0.6945 - val_accuracy: 0.5000
# Epoch 2/5
# 4/4 [==============================] - 2s 554ms/step - loss: 0.7009 - accuracy: 0.4960 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 3/5
# 4/4 [==============================] - 2s 546ms/step - loss: 0.6973 - accuracy: 0.4400 - val_loss: 0.6933 - val_accuracy: 0.5000
# Epoch 4/5
# 4/4 [==============================] - 2s 429ms/step - loss: 0.6921 - accuracy: 0.5280 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 5/5
# 4/4 [==============================] - 2s 454ms/step - loss: 0.6941 - accuracy: 0.4720 - val_loss: 0.6932 - val_accuracy: 0.5000
# Score for fold 2: Loss of 0.6931838393211365; Accuracy of 50.0%
# ------------------------------------------------------------------------
# Training for fold 3 ...
# Found 126 validated image filenames belonging to 2 classes.
# Found 31 validated image filenames belonging to 2 classes.
# Epoch 1/5
# 4/4 [==============================] - 14s 2s/step - loss: 0.7000 - accuracy: 0.4841 - val_loss: 0.6968 - val_accuracy: 0.4839
# Epoch 2/5
# 4/4 [==============================] - 2s 440ms/step - loss: 0.7041 - accuracy: 0.3889 - val_loss: 0.6933 - val_accuracy: 0.5161
# Epoch 3/5
# 4/4 [==============================] - 2s 459ms/step - loss: 0.6964 - accuracy: 0.5000 - val_loss: 0.6927 - val_accuracy: 0.5161
# Epoch 4/5
# 4/4 [==============================] - 2s 551ms/step - loss: 0.6933 - accuracy: 0.4841 - val_loss: 0.6934 - val_accuracy: 0.4839
# Epoch 5/5
# 4/4 [==============================] - 2s 565ms/step - loss: 0.7019 - accuracy: 0.4683 - val_loss: 0.7000 - val_accuracy: 0.4839
# Score for fold 3: Loss of 0.6999669671058655; Accuracy of 48.39%
# ------------------------------------------------------------------------
# Training for fold 4 ...
# Found 126 validated image filenames belonging to 2 classes.
# Found 31 validated image filenames belonging to 2 classes.
# Epoch 1/5
# 4/4 [==============================] - 11s 1s/step - loss: 0.7015 - accuracy: 0.5000 - val_loss: 0.6933 - val_accuracy: 0.5161
# Epoch 2/5
# 4/4 [==============================] - 2s 429ms/step - loss: 0.7000 - accuracy: 0.5000 - val_loss: 0.6929 - val_accuracy: 0.5161
# Epoch 3/5
# 4/4 [==============================] - 2s 446ms/step - loss: 0.6992 - accuracy: 0.4365 - val_loss: 0.6942 - val_accuracy: 0.4839
# Epoch 4/5
# 4/4 [==============================] - 2s 438ms/step - loss: 0.6938 - accuracy: 0.5000 - val_loss: 0.6936 - val_accuracy: 0.4839
# Epoch 5/5
# 4/4 [==============================] - 2s 442ms/step - loss: 0.6926 - accuracy: 0.5317 - val_loss: 0.6928 - val_accuracy: 0.5161
# Score for fold 4: Loss of 0.6928073763847351; Accuracy of 51.61%
# ------------------------------------------------------------------------
# Training for fold 5 ...
# Found 126 validated image filenames belonging to 2 classes.
# Found 31 validated image filenames belonging to 2 classes.
# Epoch 1/5
# 4/4 [==============================] - 10s 976ms/step - loss: 0.6975 - accuracy: 0.4524 - val_loss: 0.6931 - val_accuracy: 0.5161
# Epoch 2/5
# 4/4 [==============================] - 2s 563ms/step - loss: 0.6919 - accuracy: 0.5159 - val_loss: 0.6962 - val_accuracy: 0.4839
# Epoch 3/5
# 4/4 [==============================] - 2s 615ms/step - loss: 0.6945 - accuracy: 0.5079 - val_loss: 0.6984 - val_accuracy: 0.4839
# Epoch 4/5
# 4/4 [==============================] - 2s 418ms/step - loss: 0.6968 - accuracy: 0.5079 - val_loss: 0.6933 - val_accuracy: 0.4839
# Epoch 5/5
# 4/4 [==============================] - 2s 430ms/step - loss: 0.6935 - accuracy: 0.4841 - val_loss: 0.6927 - val_accuracy: 0.5161
# Score for fold 5: Loss of 0.6926798224449158; Accuracy of 51.61%
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - Loss: 0.6931803822517395 - Accuracy: 50.0%
# ------------------------------------------------------------------------
# > Fold 2 - Loss: 0.6931838393211365 - Accuracy: 50.0%
# ------------------------------------------------------------------------
# > Fold 3 - Loss: 0.6999669671058655 - Accuracy: 48.38709533214569%
# ------------------------------------------------------------------------
# > Fold 4 - Loss: 0.6928073763847351 - Accuracy: 51.61290168762207%
# ------------------------------------------------------------------------
# > Fold 5 - Loss: 0.6926798224449158 - Accuracy: 51.61290168762207%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 50.322579741477966 (+- 1.2069860585271486)
# > Loss: 0.6943636775016785
# ------------------------------------------------------------------------
# Found 67 images belonging to 2 classes.
# 3/3 [==============================] - 1s 584ms/step - loss: 0.6930 - accuracy: 0.5075
#  33%|███▎      | 2/6 [06:04<11:29, 172.30s/it]
# ------------------------------------------------------------------------
# Training for fold 1 ...
# Found 125 validated image filenames belonging to 2 classes.
# Found 32 validated image filenames belonging to 2 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 [==============================] - 0s 0us/step
# Epoch 1/5
# 4/4 [==============================] - 18s 3s/step - loss: 0.6834 - accuracy: 0.5680 - val_loss: 0.6352 - val_accuracy: 0.5938
# Epoch 2/5
# 4/4 [==============================] - 2s 431ms/step - loss: 0.6418 - accuracy: 0.6720 - val_loss: 0.6225 - val_accuracy: 0.7500
# Epoch 3/5
# 4/4 [==============================] - 2s 493ms/step - loss: 0.6131 - accuracy: 0.7120 - val_loss: 0.6087 - val_accuracy: 0.7188
# Epoch 4/5
# 4/4 [==============================] - 2s 561ms/step - loss: 0.5892 - accuracy: 0.7360 - val_loss: 0.6037 - val_accuracy: 0.7188
# Epoch 5/5
# 4/4 [==============================] - 2s 445ms/step - loss: 0.5684 - accuracy: 0.7760 - val_loss: 0.5972 - val_accuracy: 0.7188
# Score for fold 1: Loss of 0.5971577167510986; Accuracy of 71.88%
# ------------------------------------------------------------------------
# Training for fold 2 ...
# Found 125 validated image filenames belonging to 2 classes.
# Found 32 validated image filenames belonging to 2 classes.
# Epoch 1/5
# 4/4 [==============================] - 10s 1s/step - loss: 0.7109 - accuracy: 0.4880 - val_loss: 0.6569 - val_accuracy: 0.5938
# Epoch 2/5
# 4/4 [==============================] - 2s 439ms/step - loss: 0.6531 - accuracy: 0.6400 - val_loss: 0.6458 - val_accuracy: 0.6250
# Epoch 3/5
# 4/4 [==============================] - 2s 472ms/step - loss: 0.6605 - accuracy: 0.5280 - val_loss: 0.6312 - val_accuracy: 0.6562
# Epoch 4/5
# 4/4 [==============================] - 2s 464ms/step - loss: 0.6346 - accuracy: 0.6400 - val_loss: 0.6127 - val_accuracy: 0.6875
# Epoch 5/5
# 4/4 [==============================] - 2s 444ms/step - loss: 0.6211 - accuracy: 0.6800 - val_loss: 0.6011 - val_accuracy: 0.6562
# Score for fold 2: Loss of 0.6010760068893433; Accuracy of 65.62%
# ------------------------------------------------------------------------
# Training for fold 3 ...
# Found 126 validated image filenames belonging to 2 classes.
# Found 31 validated image filenames belonging to 2 classes.
# Epoch 1/5
# 4/4 [==============================] - 17s 3s/step - loss: 0.6893 - accuracy: 0.5317 - val_loss: 0.6482 - val_accuracy: 0.6452
# Epoch 2/5
# 4/4 [==============================] - 2s 559ms/step - loss: 0.6529 - accuracy: 0.6825 - val_loss: 0.6465 - val_accuracy: 0.5806
# Epoch 3/5
# 4/4 [==============================] - 2s 535ms/step - loss: 0.6221 - accuracy: 0.7222 - val_loss: 0.6397 - val_accuracy: 0.6452
# Epoch 4/5
# 4/4 [==============================] - 2s 436ms/step - loss: 0.5987 - accuracy: 0.7619 - val_loss: 0.6417 - val_accuracy: 0.6452
# Epoch 5/5
# 4/4 [==============================] - 2s 444ms/step - loss: 0.5897 - accuracy: 0.7143 - val_loss: 0.6492 - val_accuracy: 0.6129
# Score for fold 3: Loss of 0.649199903011322; Accuracy of 61.29%
# ------------------------------------------------------------------------
# Training for fold 4 ...
# Found 126 validated image filenames belonging to 2 classes.
# Found 31 validated image filenames belonging to 2 classes.
# Epoch 1/5
# 4/4 [==============================] - 9s 1s/step - loss: 0.7085 - accuracy: 0.5238 - val_loss: 0.6640 - val_accuracy: 0.5484
# Epoch 2/5
# 4/4 [==============================] - 2s 440ms/step - loss: 0.6639 - accuracy: 0.6508 - val_loss: 0.6733 - val_accuracy: 0.5484
# Epoch 3/5
# 4/4 [==============================] - 2s 434ms/step - loss: 0.6429 - accuracy: 0.6587 - val_loss: 0.6557 - val_accuracy: 0.5484
# Epoch 4/5
# 4/4 [==============================] - 2s 464ms/step - loss: 0.6199 - accuracy: 0.6825 - val_loss: 0.6536 - val_accuracy: 0.6129
# Epoch 5/5
# 4/4 [==============================] - 2s 543ms/step - loss: 0.5975 - accuracy: 0.6984 - val_loss: 0.6502 - val_accuracy: 0.5484
# Score for fold 4: Loss of 0.6502276062965393; Accuracy of 54.84%
# ------------------------------------------------------------------------
# Training for fold 5 ...
# Found 126 validated image filenames belonging to 2 classes.
# Found 31 validated image filenames belonging to 2 classes.
# Epoch 1/5
# 4/4 [==============================] - 7s 915ms/step - loss: 0.6874 - accuracy: 0.5397 - val_loss: 0.6711 - val_accuracy: 0.5806
# Epoch 2/5
# 4/4 [==============================] - 2s 563ms/step - loss: 0.6494 - accuracy: 0.6587 - val_loss: 0.6542 - val_accuracy: 0.5806
# Epoch 3/5
# 4/4 [==============================] - 2s 475ms/step - loss: 0.6266 - accuracy: 0.6905 - val_loss: 0.6377 - val_accuracy: 0.6774
# Epoch 4/5
# 4/4 [==============================] - 2s 451ms/step - loss: 0.6110 - accuracy: 0.7381 - val_loss: 0.6282 - val_accuracy: 0.6774
# Epoch 5/5
# 4/4 [==============================] - 2s 440ms/step - loss: 0.5903 - accuracy: 0.7302 - val_loss: 0.6190 - val_accuracy: 0.7097
# Score for fold 5: Loss of 0.6189822554588318; Accuracy of 70.97%
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - Loss: 0.5971577167510986 - Accuracy: 71.875%
# ------------------------------------------------------------------------
# > Fold 2 - Loss: 0.6010760068893433 - Accuracy: 65.625%
# ------------------------------------------------------------------------
# > Fold 3 - Loss: 0.649199903011322 - Accuracy: 61.29032373428345%
# ------------------------------------------------------------------------
# > Fold 4 - Loss: 0.6502276062965393 - Accuracy: 54.83871102333069%
# ------------------------------------------------------------------------
# > Fold 5 - Loss: 0.6189822554588318 - Accuracy: 70.96773982048035%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 64.9193549156189 (+- 6.3285249794967955)
# > Loss: 0.623328697681427
# ------------------------------------------------------------------------
# Found 67 images belonging to 2 classes.
# 3/3 [==============================] - 2s 996ms/step - loss: 0.6365 - accuracy: 0.5970
#  50%|█████     | 3/6 [08:31<08:01, 160.66s/it]
# ------------------------------------------------------------------------
# Training for fold 1 ...
# Found 125 validated image filenames belonging to 2 classes.
# Found 32 validated image filenames belonging to 2 classes.
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet/mobilenet_1_0_224_tf_no_top.h5
# 17225924/17225924 [==============================] - 0s 0us/step
# Epoch 1/5
# 4/4 [==============================] - 6s 811ms/step - loss: 0.7804 - accuracy: 0.3920 - val_loss: 0.7037 - val_accuracy: 0.5000
# Epoch 2/5
# 4/4 [==============================] - 2s 420ms/step - loss: 0.7443 - accuracy: 0.4800 - val_loss: 0.6797 - val_accuracy: 0.5312
# Epoch 3/5
# 4/4 [==============================] - 2s 503ms/step - loss: 0.7235 - accuracy: 0.4240 - val_loss: 0.6753 - val_accuracy: 0.6250
# Epoch 4/5
# 4/4 [==============================] - 2s 585ms/step - loss: 0.6971 - accuracy: 0.5360 - val_loss: 0.6551 - val_accuracy: 0.6562
# Epoch 5/5
# 4/4 [==============================] - 2s 515ms/step - loss: 0.6807 - accuracy: 0.5680 - val_loss: 0.6511 - val_accuracy: 0.5312
# Score for fold 1: Loss of 0.6510791778564453; Accuracy of 53.12%
# ------------------------------------------------------------------------
# Training for fold 2 ...
# Found 125 validated image filenames belonging to 2 classes.
# Found 32 validated image filenames belonging to 2 classes.
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Epoch 1/5
# 4/4 [==============================] - 4s 623ms/step - loss: 0.7139 - accuracy: 0.4640 - val_loss: 0.7024 - val_accuracy: 0.5625
# Epoch 2/5
# 4/4 [==============================] - 2s 411ms/step - loss: 0.6901 - accuracy: 0.5280 - val_loss: 0.6862 - val_accuracy: 0.5625
# Epoch 3/5
# 4/4 [==============================] - 2s 521ms/step - loss: 0.6615 - accuracy: 0.6240 - val_loss: 0.6694 - val_accuracy: 0.5625
# Epoch 4/5
# 4/4 [==============================] - 2s 537ms/step - loss: 0.6560 - accuracy: 0.5840 - val_loss: 0.6684 - val_accuracy: 0.6250
# Epoch 5/5
# 4/4 [==============================] - 2s 448ms/step - loss: 0.6370 - accuracy: 0.6160 - val_loss: 0.6422 - val_accuracy: 0.6875
# Score for fold 2: Loss of 0.6421581506729126; Accuracy of 68.75%
# ------------------------------------------------------------------------
# Training for fold 3 ...
# Found 126 validated image filenames belonging to 2 classes.
# Found 31 validated image filenames belonging to 2 classes.
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Epoch 1/5
# 4/4 [==============================] - 6s 1s/step - loss: 0.6744 - accuracy: 0.5952 - val_loss: 0.6563 - val_accuracy: 0.6452
# Epoch 2/5
# 4/4 [==============================] - 2s 408ms/step - loss: 0.6491 - accuracy: 0.6190 - val_loss: 0.6416 - val_accuracy: 0.6129
# Epoch 3/5
# 4/4 [==============================] - 2s 577ms/step - loss: 0.6223 - accuracy: 0.6746 - val_loss: 0.6249 - val_accuracy: 0.6452
# Epoch 4/5
# 4/4 [==============================] - 2s 513ms/step - loss: 0.6079 - accuracy: 0.7063 - val_loss: 0.6036 - val_accuracy: 0.7419
# Epoch 5/5
# 4/4 [==============================] - 2s 398ms/step - loss: 0.5859 - accuracy: 0.7143 - val_loss: 0.6003 - val_accuracy: 0.7097
# Score for fold 3: Loss of 0.6002849340438843; Accuracy of 70.97%
# ------------------------------------------------------------------------
# Training for fold 4 ...
# Found 126 validated image filenames belonging to 2 classes.
# Found 31 validated image filenames belonging to 2 classes.
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Epoch 1/5
# 4/4 [==============================] - 4s 644ms/step - loss: 0.6897 - accuracy: 0.5476 - val_loss: 0.7047 - val_accuracy: 0.4839
# Epoch 2/5
# 4/4 [==============================] - 2s 538ms/step - loss: 0.6574 - accuracy: 0.6429 - val_loss: 0.6867 - val_accuracy: 0.5161
# Epoch 3/5
# 4/4 [==============================] - 2s 589ms/step - loss: 0.6403 - accuracy: 0.6746 - val_loss: 0.6751 - val_accuracy: 0.5484
# Epoch 4/5
# 4/4 [==============================] - 2s 514ms/step - loss: 0.6118 - accuracy: 0.7778 - val_loss: 0.6575 - val_accuracy: 0.5484
# Epoch 5/5
# 4/4 [==============================] - 2s 584ms/step - loss: 0.5926 - accuracy: 0.7937 - val_loss: 0.6458 - val_accuracy: 0.6774
# Score for fold 4: Loss of 0.6458165645599365; Accuracy of 67.74%
# ------------------------------------------------------------------------
# Training for fold 5 ...
# Found 126 validated image filenames belonging to 2 classes.
# Found 31 validated image filenames belonging to 2 classes.
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Epoch 1/5
# 4/4 [==============================] - 4s 796ms/step - loss: 0.6822 - accuracy: 0.5714 - val_loss: 0.7019 - val_accuracy: 0.5484
# Epoch 2/5
# 4/4 [==============================] - 2s 592ms/step - loss: 0.6565 - accuracy: 0.6349 - val_loss: 0.6952 - val_accuracy: 0.5161
# Epoch 3/5
# 4/4 [==============================] - 2s 420ms/step - loss: 0.6286 - accuracy: 0.7381 - val_loss: 0.6717 - val_accuracy: 0.5806
# Epoch 4/5
# 4/4 [==============================] - 2s 405ms/step - loss: 0.6122 - accuracy: 0.7063 - val_loss: 0.6570 - val_accuracy: 0.6452
# Epoch 5/5
# 4/4 [==============================] - 2s 448ms/step - loss: 0.5947 - accuracy: 0.7381 - val_loss: 0.6467 - val_accuracy: 0.6452
# Score for fold 5: Loss of 0.6467334628105164; Accuracy of 64.52%
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - Loss: 0.6510791778564453 - Accuracy: 53.125%
# ------------------------------------------------------------------------
# > Fold 2 - Loss: 0.6421581506729126 - Accuracy: 68.75%
# ------------------------------------------------------------------------
# > Fold 3 - Loss: 0.6002849340438843 - Accuracy: 70.96773982048035%
# ------------------------------------------------------------------------
# > Fold 4 - Loss: 0.6458165645599365 - Accuracy: 67.7419364452362%
# ------------------------------------------------------------------------
# > Fold 5 - Loss: 0.6467334628105164 - Accuracy: 64.51612710952759%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 65.02016067504883 (+- 6.29987872493913)
# > Loss: 0.637214457988739
# ------------------------------------------------------------------------
# Found 67 images belonging to 2 classes.
# 3/3 [==============================] - 1s 273ms/step - loss: 0.6560 - accuracy: 0.5373
#  67%|██████▋   | 4/6 [09:55<04:20, 130.27s/it]
# ------------------------------------------------------------------------
# Training for fold 1 ...
# Found 125 validated image filenames belonging to 2 classes.
# Found 32 validated image filenames belonging to 2 classes.
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 [==============================] - 0s 0us/step
# Epoch 1/5
# 4/4 [==============================] - 8s 1s/step - loss: 0.7003 - accuracy: 0.5120 - val_loss: 0.6566 - val_accuracy: 0.6562
# Epoch 2/5
# 4/4 [==============================] - 2s 430ms/step - loss: 0.6805 - accuracy: 0.5280 - val_loss: 0.6519 - val_accuracy: 0.6562
# Epoch 3/5
# 4/4 [==============================] - 2s 426ms/step - loss: 0.6612 - accuracy: 0.5680 - val_loss: 0.6343 - val_accuracy: 0.6875
# Epoch 4/5
# 4/4 [==============================] - 2s 438ms/step - loss: 0.6344 - accuracy: 0.7120 - val_loss: 0.6290 - val_accuracy: 0.6562
# Epoch 5/5
# 4/4 [==============================] - 2s 558ms/step - loss: 0.6283 - accuracy: 0.7120 - val_loss: 0.6225 - val_accuracy: 0.6875
# Score for fold 1: Loss of 0.6225329637527466; Accuracy of 68.75%
# ------------------------------------------------------------------------
# Training for fold 2 ...
# Found 125 validated image filenames belonging to 2 classes.
# Found 32 validated image filenames belonging to 2 classes.
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Epoch 1/5
# 4/4 [==============================] - 5s 760ms/step - loss: 0.7142 - accuracy: 0.4880 - val_loss: 0.7015 - val_accuracy: 0.4062
# Epoch 2/5
# 4/4 [==============================] - 2s 486ms/step - loss: 0.6770 - accuracy: 0.5280 - val_loss: 0.6878 - val_accuracy: 0.5625
# Epoch 3/5
# 4/4 [==============================] - 2s 599ms/step - loss: 0.6671 - accuracy: 0.5600 - val_loss: 0.6714 - val_accuracy: 0.6250
# Epoch 4/5
# 4/4 [==============================] - 2s 513ms/step - loss: 0.6509 - accuracy: 0.6240 - val_loss: 0.6561 - val_accuracy: 0.6562
# Epoch 5/5
# 4/4 [==============================] - 2s 443ms/step - loss: 0.6354 - accuracy: 0.6960 - val_loss: 0.6415 - val_accuracy: 0.7188
# Score for fold 2: Loss of 0.6415159106254578; Accuracy of 71.88%
# ------------------------------------------------------------------------
# Training for fold 3 ...
# Found 126 validated image filenames belonging to 2 classes.
# Found 31 validated image filenames belonging to 2 classes.
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Epoch 1/5
# 4/4 [==============================] - 8s 2s/step - loss: 0.7223 - accuracy: 0.4683 - val_loss: 0.6690 - val_accuracy: 0.5484
# Epoch 2/5
# 4/4 [==============================] - 2s 431ms/step - loss: 0.6870 - accuracy: 0.5238 - val_loss: 0.6570 - val_accuracy: 0.6452
# Epoch 3/5
# 4/4 [==============================] - 2s 419ms/step - loss: 0.6715 - accuracy: 0.5635 - val_loss: 0.6400 - val_accuracy: 0.7742
# Epoch 4/5
# 4/4 [==============================] - 2s 412ms/step - loss: 0.6556 - accuracy: 0.6667 - val_loss: 0.6277 - val_accuracy: 0.7419
# Epoch 5/5
# 4/4 [==============================] - 2s 615ms/step - loss: 0.6333 - accuracy: 0.6905 - val_loss: 0.6135 - val_accuracy: 0.8065
# Score for fold 3: Loss of 0.6134647727012634; Accuracy of 80.65%
# ------------------------------------------------------------------------
# Training for fold 4 ...
# Found 126 validated image filenames belonging to 2 classes.
# Found 31 validated image filenames belonging to 2 classes.
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Epoch 1/5
# 4/4 [==============================] - 5s 770ms/step - loss: 0.7416 - accuracy: 0.4921 - val_loss: 0.7124 - val_accuracy: 0.5161
# Epoch 2/5
# 4/4 [==============================] - 2s 407ms/step - loss: 0.6869 - accuracy: 0.5556 - val_loss: 0.7022 - val_accuracy: 0.5484
# Epoch 3/5
# 4/4 [==============================] - 2s 609ms/step - loss: 0.6695 - accuracy: 0.5873 - val_loss: 0.6915 - val_accuracy: 0.5161
# Epoch 4/5
# 4/4 [==============================] - 2s 554ms/step - loss: 0.6486 - accuracy: 0.7222 - val_loss: 0.6898 - val_accuracy: 0.4839
# Epoch 5/5
# 4/4 [==============================] - 2s 415ms/step - loss: 0.6361 - accuracy: 0.6587 - val_loss: 0.6841 - val_accuracy: 0.5484
# Score for fold 4: Loss of 0.6841201782226562; Accuracy of 54.84%
# ------------------------------------------------------------------------
# Training for fold 5 ...
# Found 126 validated image filenames belonging to 2 classes.
# Found 31 validated image filenames belonging to 2 classes.
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Epoch 1/5
# 4/4 [==============================] - 5s 778ms/step - loss: 0.7209 - accuracy: 0.5397 - val_loss: 0.7180 - val_accuracy: 0.4839
# Epoch 2/5
# 4/4 [==============================] - 2s 597ms/step - loss: 0.7074 - accuracy: 0.5238 - val_loss: 0.7255 - val_accuracy: 0.4839
# Epoch 3/5
# 4/4 [==============================] - 2s 524ms/step - loss: 0.6864 - accuracy: 0.5635 - val_loss: 0.6734 - val_accuracy: 0.5806
# Epoch 4/5
# 4/4 [==============================] - 2s 409ms/step - loss: 0.6535 - accuracy: 0.6984 - val_loss: 0.6565 - val_accuracy: 0.5806
# Epoch 5/5
# 4/4 [==============================] - 2s 433ms/step - loss: 0.6438 - accuracy: 0.6905 - val_loss: 0.6446 - val_accuracy: 0.6452
# Score for fold 5: Loss of 0.6445875763893127; Accuracy of 64.52%
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - Loss: 0.6225329637527466 - Accuracy: 68.75%
# ------------------------------------------------------------------------
# > Fold 2 - Loss: 0.6415159106254578 - Accuracy: 71.875%
# ------------------------------------------------------------------------
# > Fold 3 - Loss: 0.6134647727012634 - Accuracy: 80.64516186714172%
# ------------------------------------------------------------------------
# > Fold 4 - Loss: 0.6841201782226562 - Accuracy: 54.83871102333069%
# ------------------------------------------------------------------------
# > Fold 5 - Loss: 0.6445875763893127 - Accuracy: 64.51612710952759%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 68.125 (+- 8.49419821396441)
# > Loss: 0.6412442803382874
# ------------------------------------------------------------------------
# Found 67 images belonging to 2 classes.
# 3/3 [==============================] - 1s 389ms/step - loss: 0.6403 - accuracy: 0.6866
#  83%|████████▎ | 5/6 [11:34<01:59, 119.04s/it]
# ------------------------------------------------------------------------
# Training for fold 1 ...
# Found 125 validated image filenames belonging to 2 classes.
# Found 32 validated image filenames belonging to 2 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet101_weights_tf_dim_ordering_tf_kernels_notop.h5
# 171446536/171446536 [==============================] - 1s 0us/step
# Epoch 1/5
# 4/4 [==============================] - 17s 2s/step - loss: 0.7140 - accuracy: 0.5280 - val_loss: 0.7249 - val_accuracy: 0.5000
# Epoch 2/5
# 4/4 [==============================] - 2s 588ms/step - loss: 0.7805 - accuracy: 0.5040 - val_loss: 0.7390 - val_accuracy: 0.5000
# Epoch 3/5
# 4/4 [==============================] - 2s 560ms/step - loss: 0.7140 - accuracy: 0.5200 - val_loss: 0.7070 - val_accuracy: 0.5000
# Epoch 4/5
# 4/4 [==============================] - 2s 558ms/step - loss: 0.7296 - accuracy: 0.4960 - val_loss: 0.7193 - val_accuracy: 0.5000
# Epoch 5/5
# 4/4 [==============================] - 3s 833ms/step - loss: 0.7090 - accuracy: 0.4960 - val_loss: 0.6924 - val_accuracy: 0.5000
# Score for fold 1: Loss of 0.6924260854721069; Accuracy of 50.0%
# ------------------------------------------------------------------------
# Training for fold 2 ...
# Found 125 validated image filenames belonging to 2 classes.
# Found 32 validated image filenames belonging to 2 classes.
# Epoch 1/5
# 4/4 [==============================] - 11s 1s/step - loss: 0.7143 - accuracy: 0.5200 - val_loss: 0.7240 - val_accuracy: 0.5000
# Epoch 2/5
# 4/4 [==============================] - 2s 571ms/step - loss: 0.7000 - accuracy: 0.5120 - val_loss: 0.7025 - val_accuracy: 0.5000
# Epoch 3/5
# 4/4 [==============================] - 2s 547ms/step - loss: 0.7483 - accuracy: 0.5040 - val_loss: 0.7233 - val_accuracy: 0.5000
# Epoch 4/5
# 4/4 [==============================] - 2s 560ms/step - loss: 0.6972 - accuracy: 0.5280 - val_loss: 0.7075 - val_accuracy: 0.5000
# Epoch 5/5
# 4/4 [==============================] - 3s 660ms/step - loss: 0.7268 - accuracy: 0.4960 - val_loss: 0.7158 - val_accuracy: 0.5000
# Score for fold 2: Loss of 0.7158222198486328; Accuracy of 50.0%
# ------------------------------------------------------------------------
# Training for fold 3 ...
# Found 126 validated image filenames belonging to 2 classes.
# Found 31 validated image filenames belonging to 2 classes.
# Epoch 1/5
# 4/4 [==============================] - 19s 3s/step - loss: 0.7982 - accuracy: 0.4841 - val_loss: 0.7096 - val_accuracy: 0.5161
# Epoch 2/5
# 4/4 [==============================] - 2s 543ms/step - loss: 0.7734 - accuracy: 0.5000 - val_loss: 0.7342 - val_accuracy: 0.5161
# Epoch 3/5
# 4/4 [==============================] - 3s 674ms/step - loss: 0.7330 - accuracy: 0.4683 - val_loss: 0.7025 - val_accuracy: 0.4839
# Epoch 4/5
# 4/4 [==============================] - 2s 526ms/step - loss: 0.7144 - accuracy: 0.5000 - val_loss: 0.7176 - val_accuracy: 0.4839
# Epoch 5/5
# 4/4 [==============================] - 2s 554ms/step - loss: 0.7065 - accuracy: 0.5000 - val_loss: 0.6961 - val_accuracy: 0.4839
# Score for fold 3: Loss of 0.6960796117782593; Accuracy of 48.39%
# ------------------------------------------------------------------------
# Training for fold 4 ...
# Found 126 validated image filenames belonging to 2 classes.
# Found 31 validated image filenames belonging to 2 classes.
# Epoch 1/5
# 4/4 [==============================] - 10s 1s/step - loss: 0.7626 - accuracy: 0.4683 - val_loss: 0.7507 - val_accuracy: 0.4839
# Epoch 2/5
# 4/4 [==============================] - 2s 533ms/step - loss: 0.7525 - accuracy: 0.5000 - val_loss: 0.7144 - val_accuracy: 0.4839
# Epoch 3/5
# 4/4 [==============================] - 3s 618ms/step - loss: 0.7174 - accuracy: 0.4365 - val_loss: 0.7163 - val_accuracy: 0.5161
# Epoch 4/5
# 4/4 [==============================] - 2s 577ms/step - loss: 0.7239 - accuracy: 0.5000 - val_loss: 0.6994 - val_accuracy: 0.5161
# Epoch 5/5
# 4/4 [==============================] - 2s 543ms/step - loss: 0.6933 - accuracy: 0.5317 - val_loss: 0.6984 - val_accuracy: 0.4839
# Score for fold 4: Loss of 0.6984398365020752; Accuracy of 48.39%
# ------------------------------------------------------------------------
# Training for fold 5 ...
# Found 126 validated image filenames belonging to 2 classes.
# Found 31 validated image filenames belonging to 2 classes.
# Epoch 1/5
# 4/4 [==============================] - 11s 1s/step - loss: 0.7038 - accuracy: 0.5397 - val_loss: 0.7364 - val_accuracy: 0.4839
# Epoch 2/5
# 4/4 [==============================] - 2s 550ms/step - loss: 0.7052 - accuracy: 0.5079 - val_loss: 0.6972 - val_accuracy: 0.4839
# Epoch 3/5
# 4/4 [==============================] - 2s 554ms/step - loss: 0.7117 - accuracy: 0.4921 - val_loss: 0.7128 - val_accuracy: 0.5161
# Epoch 4/5
# 4/4 [==============================] - 3s 654ms/step - loss: 0.7034 - accuracy: 0.5079 - val_loss: 0.7023 - val_accuracy: 0.4839
# Epoch 5/5
# 4/4 [==============================] - 2s 573ms/step - loss: 0.7188 - accuracy: 0.5079 - val_loss: 0.7297 - val_accuracy: 0.4839
# Score for fold 5: Loss of 0.729712188243866; Accuracy of 48.39%
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - Loss: 0.6924260854721069 - Accuracy: 50.0%
# ------------------------------------------------------------------------
# > Fold 2 - Loss: 0.7158222198486328 - Accuracy: 50.0%
# ------------------------------------------------------------------------
# > Fold 3 - Loss: 0.6960796117782593 - Accuracy: 48.38709533214569%
# ------------------------------------------------------------------------
# > Fold 4 - Loss: 0.6984398365020752 - Accuracy: 48.38709533214569%
# ------------------------------------------------------------------------
# > Fold 5 - Loss: 0.729712188243866 - Accuracy: 48.38709533214569%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 49.032257199287415 (+- 0.7901586879992478)
# > Loss: 0.7064959883689881
# ------------------------------------------------------------------------
# Found 67 images belonging to 2 classes.
# 3/3 [==============================] - 2s 629ms/step - loss: 0.7208 - accuracy: 0.4925
# 100%|██████████| 6/6 [14:09<00:00, 141.59s/it]

# %%
for model_name, model_1 in tqdm(list(new_model_dict.items())[6:]):
    # Special handling for "NASNetLarge" since it requires input images with size (331,331)

    fold_no = 1
    all_acc = []
    all_loss = []

    for train_indices, val_indices in kfold.split(all_files,labels):
        print('------------------------------------------------------------------------')
        print(f'Training for fold {fold_no} ...')

    # Preprocess data and build model (assuming these functions are defined)
        train_files = [all_files[i] for i in train_indices]
        val_files = [all_files[i] for i in val_indices]
        if 'NASNetLarge' in model_name:
          img_size =(331,331)
          input_shape =(331,331,3)
          train_gen, val_gen = preprocess_data_for_fold(train_files, val_files, img_size)
        elif 'InceptionResNetV2' or 'InceptionV3' or 'Xception' in model_name:
          img_size=(299,299)
          input_shape=(299,299,3)
          train_gen, val_gen = preprocess_data_for_fold(train_files, val_files, img_size)
        else:
          img_size=(224,224)
          input_shape=(224,224,3)
          train_gen, val_gen = preprocess_data_for_fold(train_files, val_files, img_size)


        model = build_model(model_1,input_shape)

    # Fit data to model
        history = model.fit(train_gen, epochs=5, validation_data=val_gen)

    # Evaluate the model on validation set
        scores = model.evaluate(val_gen, verbose=0)
        fold_val_accuracy = round(scores[1] * 100, 2)
        print(f'Score for fold {fold_no}: Loss of {scores[0]}; Accuracy of {fold_val_accuracy}%')
        all_acc.append(fold_val_accuracy)
        all_loss.append(scores[0])

    # Increase fold number
        fold_no += 1

# Provide average scores
    print('------------------------------------------------------------------------')
    print('Score per fold')
    for i in range(len(all_acc)):
        print('------------------------------------------------------------------------')
        print(f'> Fold {i+1} - Loss: {all_loss[i]} - Accuracy: {all_acc[i]}%')
    print('------------------------------------------------------------------------')
    print('Average scores for all folds:')
    print(f'> Accuracy: {np.mean(all_acc)} (+- {np.std(all_acc)})')
    print(f'> Loss: {np.mean(all_loss)}')
    print('------------------------------------------------------------------------')
    if 'NASNetLarge' in model_name:
        test_processed = test_preprocces(img_size)
    elif 'InceptionResNetV2' or 'InceptionV3' or 'Xception' in model_name:
        test_processed = test_preprocces(img_size)
    else:
        test_processed = test_preprocces(img_size)

    test_acc = model.evaluate(test_processed)

    # Calculate all relevant metrics
    model_benchmarks['model_name'].append(model_name)
    model_benchmarks['num_model_params'].append(model.count_params())
    model_benchmarks['validation_accuracy'].append(np.mean(all_acc))
    model_benchmarks['test_accuracy'].append(test_acc[-1])
# Out:
#   0%|          | 0/6 [00:00<?, ?it/s]
# ------------------------------------------------------------------------
# Training for fold 1 ...
# Found 125 validated image filenames belonging to 2 classes.
# Found 32 validated image filenames belonging to 2 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet101v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 171317808/171317808 [==============================] - 1s 0us/step
# Epoch 1/5
# 4/4 [==============================] - 15s 2s/step - loss: 0.8911 - accuracy: 0.4800 - val_loss: 0.6572 - val_accuracy: 0.5938
# Epoch 2/5
# 4/4 [==============================] - 3s 790ms/step - loss: 0.6690 - accuracy: 0.5760 - val_loss: 0.6619 - val_accuracy: 0.6250
# Epoch 3/5
# 4/4 [==============================] - 3s 641ms/step - loss: 0.6595 - accuracy: 0.5920 - val_loss: 0.6405 - val_accuracy: 0.7500
# Epoch 4/5
# 4/4 [==============================] - 2s 550ms/step - loss: 0.6180 - accuracy: 0.6880 - val_loss: 0.6292 - val_accuracy: 0.5938
# Epoch 5/5
# 4/4 [==============================] - 2s 535ms/step - loss: 0.6008 - accuracy: 0.7120 - val_loss: 0.6255 - val_accuracy: 0.5625
# Score for fold 1: Loss of 0.6255083680152893; Accuracy of 56.25%
# ------------------------------------------------------------------------
# Training for fold 2 ...
# Found 125 validated image filenames belonging to 2 classes.
# Found 32 validated image filenames belonging to 2 classes.
# Epoch 1/5
# 4/4 [==============================] - 10s 1s/step - loss: 0.6935 - accuracy: 0.5440 - val_loss: 0.6468 - val_accuracy: 0.6562
# Epoch 2/5
# 4/4 [==============================] - 2s 559ms/step - loss: 0.6548 - accuracy: 0.6160 - val_loss: 0.6176 - val_accuracy: 0.6875
# Epoch 3/5
# 4/4 [==============================] - 3s 868ms/step - loss: 0.6233 - accuracy: 0.6320 - val_loss: 0.5840 - val_accuracy: 0.6875
# Epoch 4/5
# 4/4 [==============================] - 2s 502ms/step - loss: 0.5928 - accuracy: 0.6400 - val_loss: 0.5553 - val_accuracy: 0.7500
# Epoch 5/5
# 4/4 [==============================] - 2s 513ms/step - loss: 0.5660 - accuracy: 0.7360 - val_loss: 0.5414 - val_accuracy: 0.7812
# Score for fold 2: Loss of 0.54140305519104; Accuracy of 78.12%
# ------------------------------------------------------------------------
# Training for fold 3 ...
# Found 126 validated image filenames belonging to 2 classes.
# Found 31 validated image filenames belonging to 2 classes.
# Epoch 1/5
# 4/4 [==============================] - 18s 4s/step - loss: 0.7303 - accuracy: 0.5079 - val_loss: 0.7126 - val_accuracy: 0.4516
# Epoch 2/5
# 4/4 [==============================] - 2s 549ms/step - loss: 0.6924 - accuracy: 0.5238 - val_loss: 0.7243 - val_accuracy: 0.5806
# Epoch 3/5
# 4/4 [==============================] - 2s 605ms/step - loss: 0.6524 - accuracy: 0.6111 - val_loss: 0.6778 - val_accuracy: 0.4839
# Epoch 4/5
# 4/4 [==============================] - 2s 522ms/step - loss: 0.6147 - accuracy: 0.6429 - val_loss: 0.6661 - val_accuracy: 0.5161
# Epoch 5/5
# 4/4 [==============================] - 2s 525ms/step - loss: 0.5861 - accuracy: 0.7302 - val_loss: 0.6430 - val_accuracy: 0.6452
# Score for fold 3: Loss of 0.6429896354675293; Accuracy of 64.52%
# ------------------------------------------------------------------------
# Training for fold 4 ...
# Found 126 validated image filenames belonging to 2 classes.
# Found 31 validated image filenames belonging to 2 classes.
# Epoch 1/5
# 4/4 [==============================] - 10s 1s/step - loss: 0.6667 - accuracy: 0.5794 - val_loss: 0.7323 - val_accuracy: 0.4516
# Epoch 2/5
# 4/4 [==============================] - 2s 533ms/step - loss: 0.6422 - accuracy: 0.6032 - val_loss: 0.6839 - val_accuracy: 0.5806
# Epoch 3/5
# 4/4 [==============================] - 2s 609ms/step - loss: 0.5924 - accuracy: 0.7540 - val_loss: 0.6655 - val_accuracy: 0.6129
# Epoch 4/5
# 4/4 [==============================] - 2s 604ms/step - loss: 0.5706 - accuracy: 0.7698 - val_loss: 0.6529 - val_accuracy: 0.6452
# Epoch 5/5
# 4/4 [==============================] - 2s 545ms/step - loss: 0.5403 - accuracy: 0.7778 - val_loss: 0.6445 - val_accuracy: 0.5484
# Score for fold 4: Loss of 0.644532322883606; Accuracy of 54.84%
# ------------------------------------------------------------------------
# Training for fold 5 ...
# Found 126 validated image filenames belonging to 2 classes.
# Found 31 validated image filenames belonging to 2 classes.
# Epoch 1/5
# 4/4 [==============================] - 11s 1s/step - loss: 0.7296 - accuracy: 0.5476 - val_loss: 0.6126 - val_accuracy: 0.7419
# Epoch 2/5
# 4/4 [==============================] - 2s 513ms/step - loss: 0.6762 - accuracy: 0.5873 - val_loss: 0.5914 - val_accuracy: 0.7097
# Epoch 3/5
# 4/4 [==============================] - 2s 514ms/step - loss: 0.6319 - accuracy: 0.6429 - val_loss: 0.5770 - val_accuracy: 0.7742
# Epoch 4/5
# 4/4 [==============================] - 2s 515ms/step - loss: 0.5947 - accuracy: 0.7302 - val_loss: 0.5678 - val_accuracy: 0.7419
# Epoch 5/5
# 4/4 [==============================] - 2s 593ms/step - loss: 0.5621 - accuracy: 0.7778 - val_loss: 0.5619 - val_accuracy: 0.6774
# Score for fold 5: Loss of 0.5618950128555298; Accuracy of 67.74%
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - Loss: 0.6255083680152893 - Accuracy: 56.25%
# ------------------------------------------------------------------------
# > Fold 2 - Loss: 0.54140305519104 - Accuracy: 78.12%
# ------------------------------------------------------------------------
# > Fold 3 - Loss: 0.6429896354675293 - Accuracy: 64.52%
# ------------------------------------------------------------------------
# > Fold 4 - Loss: 0.644532322883606 - Accuracy: 54.84%
# ------------------------------------------------------------------------
# > Fold 5 - Loss: 0.5618950128555298 - Accuracy: 67.74%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 64.294 (+- 8.451843822504058)
# > Loss: 0.6032656788825989
# ------------------------------------------------------------------------
# Found 67 images belonging to 2 classes.
# 3/3 [==============================] - 2s 652ms/step - loss: 0.5795 - accuracy: 0.6716
#  17%|█▋        | 1/6 [02:37<13:07, 157.48s/it]
# ------------------------------------------------------------------------
# Training for fold 1 ...
# Found 125 validated image filenames belonging to 2 classes.
# Found 32 validated image filenames belonging to 2 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 0s 0us/step
# Epoch 1/5
# 4/4 [==============================] - 9s 1s/step - loss: 0.7394 - accuracy: 0.4720 - val_loss: 0.7076 - val_accuracy: 0.5000
# Epoch 2/5
# 4/4 [==============================] - 2s 480ms/step - loss: 0.7210 - accuracy: 0.5040 - val_loss: 0.7029 - val_accuracy: 0.5000
# Epoch 3/5
# 4/4 [==============================] - 2s 470ms/step - loss: 0.6993 - accuracy: 0.4640 - val_loss: 0.6988 - val_accuracy: 0.5000
# Epoch 4/5
# 4/4 [==============================] - 2s 504ms/step - loss: 0.7035 - accuracy: 0.4960 - val_loss: 0.6993 - val_accuracy: 0.5000
# Epoch 5/5
# 4/4 [==============================] - 2s 495ms/step - loss: 0.7002 - accuracy: 0.4960 - val_loss: 0.6918 - val_accuracy: 0.5000
# Score for fold 1: Loss of 0.6917726397514343; Accuracy of 50.0%
# ------------------------------------------------------------------------
# Training for fold 2 ...
# Found 125 validated image filenames belonging to 2 classes.
# Found 32 validated image filenames belonging to 2 classes.
# Epoch 1/5
# 4/4 [==============================] - 7s 818ms/step - loss: 0.7373 - accuracy: 0.4640 - val_loss: 0.7170 - val_accuracy: 0.5000
# Epoch 2/5
# 4/4 [==============================] - 2s 461ms/step - loss: 0.7118 - accuracy: 0.4960 - val_loss: 0.6933 - val_accuracy: 0.5000
# Epoch 3/5
# 4/4 [==============================] - 2s 533ms/step - loss: 0.6933 - accuracy: 0.5040 - val_loss: 0.6969 - val_accuracy: 0.5000
# Epoch 4/5
# 4/4 [==============================] - 2s 580ms/step - loss: 0.7003 - accuracy: 0.5040 - val_loss: 0.6962 - val_accuracy: 0.5000
# Epoch 5/5
# 4/4 [==============================] - 2s 512ms/step - loss: 0.6967 - accuracy: 0.5280 - val_loss: 0.6928 - val_accuracy: 0.5000
# Score for fold 2: Loss of 0.6927955746650696; Accuracy of 50.0%
# ------------------------------------------------------------------------
# Training for fold 3 ...
# Found 126 validated image filenames belonging to 2 classes.
# Found 31 validated image filenames belonging to 2 classes.
# Epoch 1/5
# 4/4 [==============================] - 7s 1s/step - loss: 0.7104 - accuracy: 0.5238 - val_loss: 0.7080 - val_accuracy: 0.5161
# Epoch 2/5
# 4/4 [==============================] - 3s 876ms/step - loss: 0.7160 - accuracy: 0.5000 - val_loss: 0.6951 - val_accuracy: 0.5161
# Epoch 3/5
# 4/4 [==============================] - 2s 446ms/step - loss: 0.6887 - accuracy: 0.5238 - val_loss: 0.6978 - val_accuracy: 0.4839
# Epoch 4/5
# 4/4 [==============================] - 2s 548ms/step - loss: 0.7136 - accuracy: 0.5000 - val_loss: 0.7177 - val_accuracy: 0.4839
# Epoch 5/5
# 4/4 [==============================] - 2s 501ms/step - loss: 0.7066 - accuracy: 0.5000 - val_loss: 0.6931 - val_accuracy: 0.5161
# Score for fold 3: Loss of 0.6930772066116333; Accuracy of 51.61%
# ------------------------------------------------------------------------
# Training for fold 4 ...
# Found 126 validated image filenames belonging to 2 classes.
# Found 31 validated image filenames belonging to 2 classes.
# Epoch 1/5
# 4/4 [==============================] - 7s 1s/step - loss: 0.7059 - accuracy: 0.5000 - val_loss: 0.6917 - val_accuracy: 0.5161
# Epoch 2/5
# 4/4 [==============================] - 2s 488ms/step - loss: 0.7070 - accuracy: 0.5000 - val_loss: 0.7085 - val_accuracy: 0.4839
# Epoch 3/5
# 4/4 [==============================] - 2s 478ms/step - loss: 0.6949 - accuracy: 0.5000 - val_loss: 0.6911 - val_accuracy: 0.5161
# Epoch 4/5
# 4/4 [==============================] - 2s 466ms/step - loss: 0.7015 - accuracy: 0.5476 - val_loss: 0.6997 - val_accuracy: 0.5161
# Epoch 5/5
# 4/4 [==============================] - 2s 464ms/step - loss: 0.7053 - accuracy: 0.5000 - val_loss: 0.6906 - val_accuracy: 0.5161
# Score for fold 4: Loss of 0.6905995011329651; Accuracy of 51.61%
# ------------------------------------------------------------------------
# Training for fold 5 ...
# Found 126 validated image filenames belonging to 2 classes.
# Found 31 validated image filenames belonging to 2 classes.
# Epoch 1/5
# 4/4 [==============================] - 6s 804ms/step - loss: 0.8934 - accuracy: 0.5079 - val_loss: 0.7093 - val_accuracy: 0.4839
# Epoch 2/5
# 4/4 [==============================] - 2s 487ms/step - loss: 0.7054 - accuracy: 0.4762 - val_loss: 0.7313 - val_accuracy: 0.5161
# Epoch 3/5
# 4/4 [==============================] - 2s 510ms/step - loss: 0.7580 - accuracy: 0.4921 - val_loss: 0.7293 - val_accuracy: 0.5161
# Epoch 4/5
# 4/4 [==============================] - 2s 595ms/step - loss: 0.7242 - accuracy: 0.4921 - val_loss: 0.6940 - val_accuracy: 0.4839
# Epoch 5/5
# 4/4 [==============================] - 2s 540ms/step - loss: 0.7012 - accuracy: 0.4841 - val_loss: 0.7239 - val_accuracy: 0.4839
# Score for fold 5: Loss of 0.7239205241203308; Accuracy of 48.39%
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - Loss: 0.6917726397514343 - Accuracy: 50.0%
# ------------------------------------------------------------------------
# > Fold 2 - Loss: 0.6927955746650696 - Accuracy: 50.0%
# ------------------------------------------------------------------------
# > Fold 3 - Loss: 0.6930772066116333 - Accuracy: 51.61%
# ------------------------------------------------------------------------
# > Fold 4 - Loss: 0.6905995011329651 - Accuracy: 51.61%
# ------------------------------------------------------------------------
# > Fold 5 - Loss: 0.7239205241203308 - Accuracy: 48.39%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 50.322 (+- 1.2048136785412087)
# > Loss: 0.6984330892562867
# ------------------------------------------------------------------------
# Found 67 images belonging to 2 classes.
# 3/3 [==============================] - 1s 109ms/step - loss: 0.7189 - accuracy: 0.4925
#  33%|███▎      | 2/6 [04:20<08:22, 125.51s/it]
# ------------------------------------------------------------------------
# Training for fold 1 ...
# Found 125 validated image filenames belonging to 2 classes.
# Found 32 validated image filenames belonging to 2 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94668760/94668760 [==============================] - 1s 0us/step
# Epoch 1/5
# 4/4 [==============================] - 6s 906ms/step - loss: 0.7157 - accuracy: 0.5280 - val_loss: 0.7034 - val_accuracy: 0.5312
# Epoch 2/5
# 4/4 [==============================] - 2s 615ms/step - loss: 0.6618 - accuracy: 0.6560 - val_loss: 0.6823 - val_accuracy: 0.6250
# Epoch 3/5
# 4/4 [==============================] - 2s 467ms/step - loss: 0.6372 - accuracy: 0.6640 - val_loss: 0.6644 - val_accuracy: 0.6562
# Epoch 4/5
# 4/4 [==============================] - 2s 458ms/step - loss: 0.6105 - accuracy: 0.6960 - val_loss: 0.6464 - val_accuracy: 0.7188
# Epoch 5/5
# 4/4 [==============================] - 2s 465ms/step - loss: 0.5912 - accuracy: 0.7280 - val_loss: 0.6302 - val_accuracy: 0.7188
# Score for fold 1: Loss of 0.6301651000976562; Accuracy of 71.88%
# ------------------------------------------------------------------------
# Training for fold 2 ...
# Found 125 validated image filenames belonging to 2 classes.
# Found 32 validated image filenames belonging to 2 classes.
# Epoch 1/5
# 4/4 [==============================] - 7s 892ms/step - loss: 0.7158 - accuracy: 0.5120 - val_loss: 0.7287 - val_accuracy: 0.5000
# Epoch 2/5
# 4/4 [==============================] - 2s 461ms/step - loss: 0.6871 - accuracy: 0.5600 - val_loss: 0.6783 - val_accuracy: 0.6875
# Epoch 3/5
# 4/4 [==============================] - 2s 459ms/step - loss: 0.6428 - accuracy: 0.6720 - val_loss: 0.6537 - val_accuracy: 0.6875
# Epoch 4/5
# 4/4 [==============================] - 2s 492ms/step - loss: 0.6175 - accuracy: 0.7200 - val_loss: 0.6295 - val_accuracy: 0.6875
# Epoch 5/5
# 4/4 [==============================] - 2s 462ms/step - loss: 0.5875 - accuracy: 0.7120 - val_loss: 0.6223 - val_accuracy: 0.6875
# Score for fold 2: Loss of 0.6222749948501587; Accuracy of 68.75%
# ------------------------------------------------------------------------
# Training for fold 3 ...
# Found 126 validated image filenames belonging to 2 classes.
# Found 31 validated image filenames belonging to 2 classes.
# Epoch 1/5
# 4/4 [==============================] - 6s 778ms/step - loss: 0.7469 - accuracy: 0.4206 - val_loss: 0.7359 - val_accuracy: 0.5161
# Epoch 2/5
# 4/4 [==============================] - 2s 485ms/step - loss: 0.7034 - accuracy: 0.4921 - val_loss: 0.7214 - val_accuracy: 0.5161
# Epoch 3/5
# 4/4 [==============================] - 2s 476ms/step - loss: 0.6641 - accuracy: 0.6111 - val_loss: 0.6960 - val_accuracy: 0.4839
# Epoch 4/5
# 4/4 [==============================] - 2s 605ms/step - loss: 0.6252 - accuracy: 0.7698 - val_loss: 0.6813 - val_accuracy: 0.5484
# Epoch 5/5
# 4/4 [==============================] - 2s 518ms/step - loss: 0.6008 - accuracy: 0.7698 - val_loss: 0.6693 - val_accuracy: 0.6452
# Score for fold 3: Loss of 0.6693205833435059; Accuracy of 64.52%
# ------------------------------------------------------------------------
# Training for fold 4 ...
# Found 126 validated image filenames belonging to 2 classes.
# Found 31 validated image filenames belonging to 2 classes.
# Epoch 1/5
# 4/4 [==============================] - 9s 2s/step - loss: 0.7518 - accuracy: 0.5317 - val_loss: 0.7013 - val_accuracy: 0.5806
# Epoch 2/5
# 4/4 [==============================] - 2s 455ms/step - loss: 0.7094 - accuracy: 0.5238 - val_loss: 0.7327 - val_accuracy: 0.5484
# Epoch 3/5
# 4/4 [==============================] - 2s 476ms/step - loss: 0.6498 - accuracy: 0.5317 - val_loss: 0.6603 - val_accuracy: 0.5806
# Epoch 4/5
# 4/4 [==============================] - 2s 448ms/step - loss: 0.6106 - accuracy: 0.7063 - val_loss: 0.6582 - val_accuracy: 0.5806
# Epoch 5/5
# 4/4 [==============================] - 2s 552ms/step - loss: 0.6159 - accuracy: 0.6825 - val_loss: 0.6481 - val_accuracy: 0.6129
# Score for fold 4: Loss of 0.6481137275695801; Accuracy of 61.29%
# ------------------------------------------------------------------------
# Training for fold 5 ...
# Found 126 validated image filenames belonging to 2 classes.
# Found 31 validated image filenames belonging to 2 classes.
# Epoch 1/5
# 4/4 [==============================] - 6s 758ms/step - loss: 0.7012 - accuracy: 0.5714 - val_loss: 0.6684 - val_accuracy: 0.6129
# Epoch 2/5
# 4/4 [==============================] - 2s 448ms/step - loss: 0.6741 - accuracy: 0.6111 - val_loss: 0.6429 - val_accuracy: 0.6129
# Epoch 3/5
# 4/4 [==============================] - 2s 619ms/step - loss: 0.6561 - accuracy: 0.5952 - val_loss: 0.6367 - val_accuracy: 0.6774
# Epoch 4/5
# 4/4 [==============================] - 2s 541ms/step - loss: 0.6245 - accuracy: 0.6667 - val_loss: 0.6031 - val_accuracy: 0.7419
# Epoch 5/5
# 4/4 [==============================] - 2s 468ms/step - loss: 0.5966 - accuracy: 0.7540 - val_loss: 0.5864 - val_accuracy: 0.7097
# Score for fold 5: Loss of 0.5863715410232544; Accuracy of 70.97%
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - Loss: 0.6301651000976562 - Accuracy: 71.88%
# ------------------------------------------------------------------------
# > Fold 2 - Loss: 0.6222749948501587 - Accuracy: 68.75%
# ------------------------------------------------------------------------
# > Fold 3 - Loss: 0.6693205833435059 - Accuracy: 64.52%
# ------------------------------------------------------------------------
# > Fold 4 - Loss: 0.6481137275695801 - Accuracy: 61.29%
# ------------------------------------------------------------------------
# > Fold 5 - Loss: 0.5863715410232544 - Accuracy: 70.97%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 67.482 (+- 4.005762848696862)
# > Loss: 0.631249189376831
# ------------------------------------------------------------------------
# Found 67 images belonging to 2 classes.
# 3/3 [==============================] - 1s 111ms/step - loss: 0.6178 - accuracy: 0.7164
#  50%|█████     | 3/6 [06:02<05:43, 114.59s/it]
# ------------------------------------------------------------------------
# Training for fold 1 ...
# Found 125 validated image filenames belonging to 2 classes.
# Found 32 validated image filenames belonging to 2 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 0s 0us/step
# Epoch 1/5
# 4/4 [==============================] - 22s 4s/step - loss: 0.7097 - accuracy: 0.4960 - val_loss: 0.6998 - val_accuracy: 0.5000
# Epoch 2/5
# 4/4 [==============================] - 2s 474ms/step - loss: 0.6984 - accuracy: 0.4960 - val_loss: 0.6928 - val_accuracy: 0.4375
# Epoch 3/5
# 4/4 [==============================] - 2s 524ms/step - loss: 0.6919 - accuracy: 0.5680 - val_loss: 0.6933 - val_accuracy: 0.5000
# Epoch 4/5
# 4/4 [==============================] - 2s 622ms/step - loss: 0.6915 - accuracy: 0.5040 - val_loss: 0.6933 - val_accuracy: 0.5000
# Epoch 5/5
# 4/4 [==============================] - 2s 569ms/step - loss: 0.6911 - accuracy: 0.5040 - val_loss: 0.6919 - val_accuracy: 0.5000
# Score for fold 1: Loss of 0.691937267780304; Accuracy of 50.0%
# ------------------------------------------------------------------------
# Training for fold 2 ...
# Found 125 validated image filenames belonging to 2 classes.
# Found 32 validated image filenames belonging to 2 classes.
# Epoch 1/5
# 4/4 [==============================] - 3s 622ms/step - loss: 0.7055 - accuracy: 0.4960 - val_loss: 0.6993 - val_accuracy: 0.5000
# Epoch 2/5
# 4/4 [==============================] - 2s 514ms/step - loss: 0.6994 - accuracy: 0.4480 - val_loss: 0.6979 - val_accuracy: 0.4062
# Epoch 3/5
# 4/4 [==============================] - 2s 492ms/step - loss: 0.6979 - accuracy: 0.3920 - val_loss: 0.6967 - val_accuracy: 0.4062
# Epoch 4/5
# 4/4 [==============================] - 2s 602ms/step - loss: 0.6971 - accuracy: 0.4160 - val_loss: 0.6957 - val_accuracy: 0.5312
# Epoch 5/5
# 4/4 [==============================] - 2s 638ms/step - loss: 0.6961 - accuracy: 0.4800 - val_loss: 0.6946 - val_accuracy: 0.5000
# Score for fold 2: Loss of 0.6946120262145996; Accuracy of 50.0%
# ------------------------------------------------------------------------
# Training for fold 3 ...
# Found 126 validated image filenames belonging to 2 classes.
# Found 31 validated image filenames belonging to 2 classes.
# Epoch 1/5
# 4/4 [==============================] - 22s 4s/step - loss: 0.7017 - accuracy: 0.5000 - val_loss: 0.6999 - val_accuracy: 0.4839
# Epoch 2/5
# 4/4 [==============================] - 2s 581ms/step - loss: 0.6937 - accuracy: 0.5000 - val_loss: 0.6942 - val_accuracy: 0.4839
# Epoch 3/5
# 4/4 [==============================] - 2s 621ms/step - loss: 0.6910 - accuracy: 0.5952 - val_loss: 0.6921 - val_accuracy: 0.5161
# Epoch 4/5
# 4/4 [==============================] - 2s 507ms/step - loss: 0.6908 - accuracy: 0.5000 - val_loss: 0.6909 - val_accuracy: 0.5161
# Epoch 5/5
# 4/4 [==============================] - 2s 492ms/step - loss: 0.6910 - accuracy: 0.5079 - val_loss: 0.6899 - val_accuracy: 0.5161
# Score for fold 3: Loss of 0.6899148225784302; Accuracy of 51.61%
# ------------------------------------------------------------------------
# Training for fold 4 ...
# Found 126 validated image filenames belonging to 2 classes.
# Found 31 validated image filenames belonging to 2 classes.
# Epoch 1/5
# 4/4 [==============================] - 3s 611ms/step - loss: 0.6887 - accuracy: 0.5476 - val_loss: 0.6887 - val_accuracy: 0.6129
# Epoch 2/5
# 4/4 [==============================] - 2s 556ms/step - loss: 0.6873 - accuracy: 0.6349 - val_loss: 0.6885 - val_accuracy: 0.5806
# Epoch 3/5
# 4/4 [==============================] - 2s 626ms/step - loss: 0.6844 - accuracy: 0.7143 - val_loss: 0.6877 - val_accuracy: 0.6452
# Epoch 4/5
# 4/4 [==============================] - 2s 514ms/step - loss: 0.6832 - accuracy: 0.7540 - val_loss: 0.6870 - val_accuracy: 0.6774
# Epoch 5/5
# 4/4 [==============================] - 2s 484ms/step - loss: 0.6827 - accuracy: 0.7063 - val_loss: 0.6858 - val_accuracy: 0.6774
# Score for fold 4: Loss of 0.6858382821083069; Accuracy of 67.74%
# ------------------------------------------------------------------------
# Training for fold 5 ...
# Found 126 validated image filenames belonging to 2 classes.
# Found 31 validated image filenames belonging to 2 classes.
# Epoch 1/5
# 4/4 [==============================] - 3s 603ms/step - loss: 0.7012 - accuracy: 0.4762 - val_loss: 0.6880 - val_accuracy: 0.6774
# Epoch 2/5
# 4/4 [==============================] - 2s 536ms/step - loss: 0.6919 - accuracy: 0.5556 - val_loss: 0.6887 - val_accuracy: 0.5161
# Epoch 3/5
# 4/4 [==============================] - 2s 607ms/step - loss: 0.6910 - accuracy: 0.5476 - val_loss: 0.6878 - val_accuracy: 0.5161
# Epoch 4/5
# 4/4 [==============================] - 2s 510ms/step - loss: 0.6895 - accuracy: 0.5635 - val_loss: 0.6870 - val_accuracy: 0.5161
# Epoch 5/5
# 4/4 [==============================] - 2s 606ms/step - loss: 0.6897 - accuracy: 0.5238 - val_loss: 0.6873 - val_accuracy: 0.4839
# Score for fold 5: Loss of 0.6873444318771362; Accuracy of 48.39%
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - Loss: 0.691937267780304 - Accuracy: 50.0%
# ------------------------------------------------------------------------
# > Fold 2 - Loss: 0.6946120262145996 - Accuracy: 50.0%
# ------------------------------------------------------------------------
# > Fold 3 - Loss: 0.6899148225784302 - Accuracy: 51.61%
# ------------------------------------------------------------------------
# > Fold 4 - Loss: 0.6858382821083069 - Accuracy: 67.74%
# ------------------------------------------------------------------------
# > Fold 5 - Loss: 0.6873444318771362 - Accuracy: 48.39%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 53.548 (+- 7.168685793086483)
# > Loss: 0.6899293661117554
# ------------------------------------------------------------------------
# Found 67 images belonging to 2 classes.
# 3/3 [==============================] - 2s 986ms/step - loss: 0.6910 - accuracy: 0.4925
#  67%|██████▋   | 4/6 [08:13<04:02, 121.18s/it]
# ------------------------------------------------------------------------
# Training for fold 1 ...
# Found 125 validated image filenames belonging to 2 classes.
# Found 32 validated image filenames belonging to 2 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 [==============================] - 0s 0us/step
# Epoch 1/5
# 4/4 [==============================] - 4s 818ms/step - loss: 0.7558 - accuracy: 0.4960 - val_loss: 0.7370 - val_accuracy: 0.5000
# Epoch 2/5
# 4/4 [==============================] - 2s 537ms/step - loss: 0.7140 - accuracy: 0.4960 - val_loss: 0.7091 - val_accuracy: 0.5000
# Epoch 3/5
# 4/4 [==============================] - 2s 527ms/step - loss: 0.6957 - accuracy: 0.4880 - val_loss: 0.7000 - val_accuracy: 0.4062
# Epoch 4/5
# 4/4 [==============================] - 2s 536ms/step - loss: 0.6893 - accuracy: 0.5440 - val_loss: 0.7019 - val_accuracy: 0.5000
# Epoch 5/5
# 4/4 [==============================] - 2s 562ms/step - loss: 0.6901 - accuracy: 0.5040 - val_loss: 0.7041 - val_accuracy: 0.5000
# Score for fold 1: Loss of 0.7041358947753906; Accuracy of 50.0%
# ------------------------------------------------------------------------
# Training for fold 2 ...
# Found 125 validated image filenames belonging to 2 classes.
# Found 32 validated image filenames belonging to 2 classes.
# Epoch 1/5
# 4/4 [==============================] - 4s 639ms/step - loss: 0.7091 - accuracy: 0.4960 - val_loss: 0.6919 - val_accuracy: 0.5000
# Epoch 2/5
# 4/4 [==============================] - 2s 516ms/step - loss: 0.6948 - accuracy: 0.5040 - val_loss: 0.6890 - val_accuracy: 0.6562
# Epoch 3/5
# 4/4 [==============================] - 2s 572ms/step - loss: 0.6931 - accuracy: 0.4880 - val_loss: 0.6885 - val_accuracy: 0.5000
# Epoch 4/5
# 4/4 [==============================] - 2s 515ms/step - loss: 0.6925 - accuracy: 0.4960 - val_loss: 0.6879 - val_accuracy: 0.5000
# Epoch 5/5
# 4/4 [==============================] - 2s 547ms/step - loss: 0.6918 - accuracy: 0.5120 - val_loss: 0.6861 - val_accuracy: 0.5312
# Score for fold 2: Loss of 0.6860795021057129; Accuracy of 53.12%
# ------------------------------------------------------------------------
# Training for fold 3 ...
# Found 126 validated image filenames belonging to 2 classes.
# Found 31 validated image filenames belonging to 2 classes.
# Epoch 1/5
# 4/4 [==============================] - 4s 661ms/step - loss: 0.8358 - accuracy: 0.5000 - val_loss: 0.7721 - val_accuracy: 0.5161
# Epoch 2/5
# 4/4 [==============================] - 2s 542ms/step - loss: 0.7701 - accuracy: 0.5000 - val_loss: 0.7266 - val_accuracy: 0.5161
# Epoch 3/5
# 4/4 [==============================] - 2s 542ms/step - loss: 0.7256 - accuracy: 0.5000 - val_loss: 0.7013 - val_accuracy: 0.5161
# Epoch 4/5
# 4/4 [==============================] - 2s 550ms/step - loss: 0.7027 - accuracy: 0.5000 - val_loss: 0.6924 - val_accuracy: 0.5161
# Epoch 5/5
# 4/4 [==============================] - 3s 809ms/step - loss: 0.6920 - accuracy: 0.5238 - val_loss: 0.6935 - val_accuracy: 0.4839
# Score for fold 3: Loss of 0.6935397982597351; Accuracy of 48.39%
# ------------------------------------------------------------------------
# Training for fold 4 ...
# Found 126 validated image filenames belonging to 2 classes.
# Found 31 validated image filenames belonging to 2 classes.
# Epoch 1/5
# 4/4 [==============================] - 3s 656ms/step - loss: 0.7301 - accuracy: 0.5000 - val_loss: 0.7053 - val_accuracy: 0.5161
# Epoch 2/5
# 4/4 [==============================] - 2s 519ms/step - loss: 0.7058 - accuracy: 0.5000 - val_loss: 0.6960 - val_accuracy: 0.5161
# Epoch 3/5
# 4/4 [==============================] - 2s 561ms/step - loss: 0.6892 - accuracy: 0.4921 - val_loss: 0.6954 - val_accuracy: 0.4516
# Epoch 4/5
# 4/4 [==============================] - 3s 829ms/step - loss: 0.6880 - accuracy: 0.5794 - val_loss: 0.6965 - val_accuracy: 0.4516
# Epoch 5/5
# 4/4 [==============================] - 2s 509ms/step - loss: 0.6882 - accuracy: 0.5714 - val_loss: 0.6967 - val_accuracy: 0.5161
# Score for fold 4: Loss of 0.6967150568962097; Accuracy of 51.61%
# ------------------------------------------------------------------------
# Training for fold 5 ...
# Found 126 validated image filenames belonging to 2 classes.
# Found 31 validated image filenames belonging to 2 classes.
# Epoch 1/5
# 4/4 [==============================] - 3s 623ms/step - loss: 0.6957 - accuracy: 0.4921 - val_loss: 0.6939 - val_accuracy: 0.4839
# Epoch 2/5
# 4/4 [==============================] - 2s 564ms/step - loss: 0.6907 - accuracy: 0.5159 - val_loss: 0.6955 - val_accuracy: 0.5161
# Epoch 3/5
# 4/4 [==============================] - 3s 816ms/step - loss: 0.6891 - accuracy: 0.5714 - val_loss: 0.6946 - val_accuracy: 0.5484
# Epoch 4/5
# 4/4 [==============================] - 2s 510ms/step - loss: 0.6872 - accuracy: 0.5873 - val_loss: 0.6940 - val_accuracy: 0.5484
# Epoch 5/5
# 4/4 [==============================] - 2s 519ms/step - loss: 0.6860 - accuracy: 0.5794 - val_loss: 0.6935 - val_accuracy: 0.5484
# Score for fold 5: Loss of 0.693475067615509; Accuracy of 54.84%
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - Loss: 0.7041358947753906 - Accuracy: 50.0%
# ------------------------------------------------------------------------
# > Fold 2 - Loss: 0.6860795021057129 - Accuracy: 53.12%
# ------------------------------------------------------------------------
# > Fold 3 - Loss: 0.6935397982597351 - Accuracy: 48.39%
# ------------------------------------------------------------------------
# > Fold 4 - Loss: 0.6967150568962097 - Accuracy: 51.61%
# ------------------------------------------------------------------------
# > Fold 5 - Loss: 0.693475067615509 - Accuracy: 54.84%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 51.592000000000006 (+- 2.2659161502579925)
# > Loss: 0.6947890639305114
# ------------------------------------------------------------------------
# Found 67 images belonging to 2 classes.
# 3/3 [==============================] - 1s 162ms/step - loss: 0.6869 - accuracy: 0.5075
#  83%|████████▎ | 5/6 [09:39<01:48, 108.45s/it]
# ------------------------------------------------------------------------
# Training for fold 1 ...
# Found 125 validated image filenames belonging to 2 classes.
# Found 32 validated image filenames belonging to 2 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 [==============================] - 0s 0us/step
# Epoch 1/5
# 4/4 [==============================] - 17s 3s/step - loss: 0.7035 - accuracy: 0.4800 - val_loss: 0.6864 - val_accuracy: 0.5625
# Epoch 2/5
# 4/4 [==============================] - 2s 543ms/step - loss: 0.6835 - accuracy: 0.5760 - val_loss: 0.6750 - val_accuracy: 0.6250
# Epoch 3/5
# 4/4 [==============================] - 2s 496ms/step - loss: 0.6578 - accuracy: 0.6800 - val_loss: 0.6629 - val_accuracy: 0.6562
# Epoch 4/5
# 4/4 [==============================] - 2s 497ms/step - loss: 0.6401 - accuracy: 0.7600 - val_loss: 0.6548 - val_accuracy: 0.7812
# Epoch 5/5
# 4/4 [==============================] - 2s 529ms/step - loss: 0.6230 - accuracy: 0.7520 - val_loss: 0.6444 - val_accuracy: 0.6875
# Score for fold 1: Loss of 0.6444283723831177; Accuracy of 68.75%
# ------------------------------------------------------------------------
# Training for fold 2 ...
# Found 125 validated image filenames belonging to 2 classes.
# Found 32 validated image filenames belonging to 2 classes.
# Epoch 1/5
# 4/4 [==============================] - 7s 795ms/step - loss: 0.6877 - accuracy: 0.5680 - val_loss: 0.6719 - val_accuracy: 0.6562
# Epoch 2/5
# 4/4 [==============================] - 2s 504ms/step - loss: 0.6698 - accuracy: 0.6400 - val_loss: 0.6536 - val_accuracy: 0.6875
# Epoch 3/5
# 4/4 [==============================] - 2s 507ms/step - loss: 0.6566 - accuracy: 0.6960 - val_loss: 0.6335 - val_accuracy: 0.7500
# Epoch 4/5
# 4/4 [==============================] - 2s 582ms/step - loss: 0.6421 - accuracy: 0.7200 - val_loss: 0.6168 - val_accuracy: 0.7500
# Epoch 5/5
# 4/4 [==============================] - 2s 603ms/step - loss: 0.6310 - accuracy: 0.7440 - val_loss: 0.6043 - val_accuracy: 0.7500
# Score for fold 2: Loss of 0.6043002605438232; Accuracy of 75.0%
# ------------------------------------------------------------------------
# Training for fold 3 ...
# Found 126 validated image filenames belonging to 2 classes.
# Found 31 validated image filenames belonging to 2 classes.
# Epoch 1/5
# 4/4 [==============================] - 15s 4s/step - loss: 0.7007 - accuracy: 0.5238 - val_loss: 0.6943 - val_accuracy: 0.4839
# Epoch 2/5
# 4/4 [==============================] - 3s 610ms/step - loss: 0.6733 - accuracy: 0.6111 - val_loss: 0.6827 - val_accuracy: 0.5161
# Epoch 3/5
# 4/4 [==============================] - 2s 593ms/step - loss: 0.6535 - accuracy: 0.6667 - val_loss: 0.6672 - val_accuracy: 0.5484
# Epoch 4/5
# 4/4 [==============================] - 2s 618ms/step - loss: 0.6360 - accuracy: 0.7302 - val_loss: 0.6611 - val_accuracy: 0.5806
# Epoch 5/5
# 4/4 [==============================] - 2s 574ms/step - loss: 0.6164 - accuracy: 0.7540 - val_loss: 0.6499 - val_accuracy: 0.6129
# Score for fold 3: Loss of 0.6498538255691528; Accuracy of 61.29%
# ------------------------------------------------------------------------
# Training for fold 4 ...
# Found 126 validated image filenames belonging to 2 classes.
# Found 31 validated image filenames belonging to 2 classes.
# Epoch 1/5
# 4/4 [==============================] - 6s 803ms/step - loss: 0.7114 - accuracy: 0.4603 - val_loss: 0.6988 - val_accuracy: 0.5161
# Epoch 2/5
# 4/4 [==============================] - 2s 558ms/step - loss: 0.6837 - accuracy: 0.5238 - val_loss: 0.6881 - val_accuracy: 0.4839
# Epoch 3/5
# 4/4 [==============================] - 2s 513ms/step - loss: 0.6695 - accuracy: 0.5952 - val_loss: 0.6700 - val_accuracy: 0.6129
# Epoch 4/5
# 4/4 [==============================] - 2s 552ms/step - loss: 0.6514 - accuracy: 0.6429 - val_loss: 0.6624 - val_accuracy: 0.6129
# Epoch 5/5
# 4/4 [==============================] - 3s 636ms/step - loss: 0.6357 - accuracy: 0.6825 - val_loss: 0.6567 - val_accuracy: 0.6452
# Score for fold 4: Loss of 0.6566996574401855; Accuracy of 64.52%
# ------------------------------------------------------------------------
# Training for fold 5 ...
# Found 126 validated image filenames belonging to 2 classes.
# Found 31 validated image filenames belonging to 2 classes.
# Epoch 1/5
# 4/4 [==============================] - 6s 790ms/step - loss: 0.7117 - accuracy: 0.4683 - val_loss: 0.6859 - val_accuracy: 0.5806
# Epoch 2/5
# 4/4 [==============================] - 2s 547ms/step - loss: 0.6879 - accuracy: 0.5397 - val_loss: 0.6882 - val_accuracy: 0.5484
# Epoch 3/5
# 4/4 [==============================] - 2s 642ms/step - loss: 0.6677 - accuracy: 0.5635 - val_loss: 0.6702 - val_accuracy: 0.6129
# Epoch 4/5
# 4/4 [==============================] - 2s 543ms/step - loss: 0.6487 - accuracy: 0.7063 - val_loss: 0.6568 - val_accuracy: 0.7419
# Epoch 5/5
# 4/4 [==============================] - 2s 497ms/step - loss: 0.6349 - accuracy: 0.7857 - val_loss: 0.6491 - val_accuracy: 0.6774
# Score for fold 5: Loss of 0.6491423845291138; Accuracy of 67.74%
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - Loss: 0.6444283723831177 - Accuracy: 68.75%
# ------------------------------------------------------------------------
# > Fold 2 - Loss: 0.6043002605438232 - Accuracy: 75.0%
# ------------------------------------------------------------------------
# > Fold 3 - Loss: 0.6498538255691528 - Accuracy: 61.29%
# ------------------------------------------------------------------------
# > Fold 4 - Loss: 0.6566996574401855 - Accuracy: 64.52%
# ------------------------------------------------------------------------
# > Fold 5 - Loss: 0.6491423845291138 - Accuracy: 67.74%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 67.46000000000001 (+- 4.5892613784791125)
# > Loss: 0.6408849000930786
# ------------------------------------------------------------------------
# Found 67 images belonging to 2 classes.
# 3/3 [==============================] - 2s 774ms/step - loss: 0.6628 - accuracy: 0.6716
# 100%|██████████| 6/6 [11:48<00:00, 118.06s/it]

# %%
# Convert Results to DataFrame for easy viewing
benchmark_df = pd.DataFrame(model_benchmarks)
benchmark_df.sort_values('num_model_params', inplace=True) # sort in ascending order of num_model_params column
benchmark_df
# Out:
#         model_name  num_model_params  validation_accuracy  test_accuracy
# 4      MobileNetV2           2259265            68.125000       0.686567
# 3        MobileNet           3229889            65.020161       0.537313
# 1   EfficientNetB0           4050852            50.322580       0.507463
# 0      DenseNet121           7038529            51.532258       0.552239
# 9            VGG16          14715201            53.548000       0.492537
# 10           VGG19          20024897            51.592000       0.507463
# 11        Xception          20863529            67.460000       0.671642
# 2      InceptionV3          21804833            64.919355       0.597015
# 8       ResNet50V2          23566849            67.482000       0.716418
# 7         ResNet50          23589761            50.322000       0.492537
# 6      ResNet101V2          42628609            64.294000       0.671642
# 5        ResNet101          42660225            49.032257       0.492537

# %%
markers=[".",",","o","v","^","<",">","1","2","3","4","8","s"]

# %%
len(markers)
# Out:
# 13

# %%
plt.figure(figsize=(7,5))
for row in benchmark_df.itertuples():
    plt.scatter(row.num_model_params, row.validation_accuracy, label=row.model_name, marker=markers[row.Index], s=150, linewidths=2)
plt.xscale('log')
plt.xlabel('Number of Parameters in Model')
plt.ylabel('Cross validation Accuracy after 5 Epochs')
plt.title('Cross validation Accuracy vs Model Size')
plt.legend(bbox_to_anchor=(1, 1), loc='upper left'); # Move legend out of the plot

# %%
plt.figure(figsize=(7,5))
for row in benchmark_df.itertuples():
    plt.scatter(row.num_model_params, row.test_accuracy, label=row.model_name, marker=markers[row.Index], s=150, linewidths=2)
plt.xscale('log')
plt.xlabel('Number of Parameters in Model')
plt.ylabel('Test Accuracy after 5 Epochs')
plt.title('Test Accuracy vs Model Size')
plt.legend(bbox_to_anchor=(1, 1), loc='upper left'); # Move legend out of the plot
